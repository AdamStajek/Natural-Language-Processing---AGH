# %%
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
from nltk.corpus import wordnet
from collections import Counter
import regex as re
from datasets import load_dataset
from nltk.tokenize import word_tokenize
import numpy as np
import json

# %%
data = load_dataset("Salesforce/wikitext", 'wikitext-103-raw-v1', trust_remote_code=True)
texts = [item["text"] for item in data['train']]
dataset = []
for text in texts:
    dataset.extend(word_tokenize(text))
dataset = dataset[:50000000]
print(len(dataset))
# Out:
# 50000000

# %%
def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
dataset = np.array(dataset)
tagged_dataset = pos_tag(dataset)
tagged_dataset
# Out:
# [('=', 'JJ'),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('III', 'NNP'),
#  ('=', 'NNP'),
#  ('Senjō', 'NNP'),
#  ('no', 'DT'),
#  ('Valkyria', 'NNP'),
#  ('3', 'CD'),
#  (':', ':'),
#  ('Unrecorded', 'VBN'),
#  ('Chronicles', 'NNP'),
#  ('(', '('),
#  ('Japanese', 'JJ'),
#  (':', ':'),
#  ('戦場のヴァルキュリア3', 'NN'),
#  (',', ','),
#  ('lit', 'NN'),
#  ('.', '.'),
#  ('Valkyria', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Battlefield', 'NNP'),
#  ('3', 'CD'),
#  (')', ')'),
#  (',', ','),
#  ('commonly', 'RB'),
#  ('referred', 'VBD'),
#  ('to', 'TO'),
#  ('as', 'IN'),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('III', 'NNP'),
#  ('outside', 'IN'),
#  ('Japan', 'NNP'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('tactical', 'JJ'),
#  ('role', 'NN'),
#  ('@', 'SYM'),
#  ('-', ':'),
#  ('@', 'NN'),
#  ('playing', 'VBG'),
#  ('video', 'JJ'),
#  ('game', 'NN'),
#  ('developed', 'VBN'),
#  ('by', 'IN'),
#  ('Sega', 'NNP'),
#  ('and', 'CC'),
#  ('Media.Vision', 'NNP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('PlayStation', 'NNP'),
#  ('Portable', 'NNP'),
#  ('.', '.'),
#  ('Released', 'VBN'),
#  ('in', 'IN'),
#  ('January', 'NNP'),
#  ('2011', 'CD'),
#  ('in', 'IN'),
#  ('Japan', 'NNP'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('third', 'JJ'),
#  ('game', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('Valkyria', 'NNP'),
#  ('series', 'NN'),
#  ('.', '.'),
#  ('Employing', 'VBG'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('fusion', 'NN'),
#  ('of', 'IN'),
#  ('tactical', 'JJ'),
#  ('and', 'CC'),
#  ('real', 'JJ'),
#  ('@', 'NNP'),
#  ('-', ':'),
#  ('@', 'NN'),
#  ('time', 'NN'),
#  ('gameplay', 'NN'),
#  ('as', 'IN'),
#  ('its', 'PRP$'),
#  ('predecessors', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('story', 'NN'),
#  ('runs', 'VBZ'),
#  ('parallel', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('game', 'NN'),
#  ('and', 'CC'),
#  ('follows', 'VBZ'),
#  ('the', 'DT'),
#  ('``', '``'),
#  ('Nameless', 'NNP'),
#  ('``', '``'),
#  (',', ','),
#  ('a', 'DT'),
#  ('penal', 'JJ'),
#  ('military', 'JJ'),
#  ('unit', 'NN'),
#  ('serving', 'VBG'),
#  ('the', 'DT'),
#  ('nation', 'NN'),
#  ('of', 'IN'),
#  ('Gallia', 'NNP'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('Second', 'NNP'),
#  ('Europan', 'NNP'),
#  ('War', 'NNP'),
#  ('who', 'WP'),
#  ('perform', 'VBP'),
#  ('secret', 'JJ'),
#  ('black', 'JJ'),
#  ('operations', 'NNS'),
#  ('and', 'CC'),
#  ('are', 'VBP'),
#  ('pitted', 'VBN'),
#  ('against', 'IN'),
#  ('the', 'DT'),
#  ('Imperial', 'NNP'),
#  ('unit', 'NN'),
#  ('``', '``'),
#  ('Calamaty', 'NNP'),
#  ('Raven', 'NNP'),
#  ('``', '``'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('game', 'NN'),
#  ('began', 'VBD'),
#  ('development', 'NN'),
#  ('in', 'IN'),
#  ('2010', 'CD'),
#  (',', ','),
#  ('carrying', 'VBG'),
#  ('over', 'RP'),
#  ('a', 'DT'),
#  ('large', 'JJ'),
#  ('portion', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('work', 'NN'),
#  ('done', 'VBN'),
#  ('on', 'IN'),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('II', 'NNP'),
#  ('.', '.'),
#  ('While', 'IN'),
#  ('it', 'PRP'),
#  ('retained', 'VBD'),
#  ('the', 'DT'),
#  ('standard', 'JJ'),
#  ('features', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('series', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('also', 'RB'),
#  ('underwent', 'JJ'),
#  ('multiple', 'JJ'),
#  ('adjustments', 'NNS'),
#  (',', ','),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('making', 'VBG'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ('more', 'RBR'),
#  ('forgiving', 'NN'),
#  ('for', 'IN'),
#  ('series', 'NN'),
#  ('newcomers', 'NNS'),
#  ('.', '.'),
#  ('Character', 'NNP'),
#  ('designer', 'NN'),
#  ('Raita', 'NNP'),
#  ('Honjou', 'NNP'),
#  ('and', 'CC'),
#  ('composer', 'NN'),
#  ('Hitoshi', 'NNP'),
#  ('Sakimoto', 'NNP'),
#  ('both', 'DT'),
#  ('returned', 'VBN'),
#  ('from', 'IN'),
#  ('previous', 'JJ'),
#  ('entries', 'NNS'),
#  (',', ','),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('II', 'NNP'),
#  ('director', 'NN'),
#  ('Takeshi', 'NNP'),
#  ('Ozawa', 'NNP'),
#  ('.', '.'),
#  ('A', 'NNP'),
#  ('large', 'JJ'),
#  ('team', 'NN'),
#  ('of', 'IN'),
#  ('writers', 'NNS'),
#  ('handled', 'VBD'),
#  ('the', 'DT'),
#  ('script', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('game', 'NN'),
#  ("'s", 'POS'),
#  ('opening', 'JJ'),
#  ('theme', 'NN'),
#  ('was', 'VBD'),
#  ('sung', 'VBN'),
#  ('by', 'IN'),
#  ('May', 'NNP'),
#  ("'n", 'NNP'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('met', 'VBD'),
#  ('with', 'IN'),
#  ('positive', 'JJ'),
#  ('sales', 'NNS'),
#  ('in', 'IN'),
#  ('Japan', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('was', 'VBD'),
#  ('praised', 'VBN'),
#  ('by', 'IN'),
#  ('both', 'DT'),
#  ('Japanese', 'NNP'),
#  ('and', 'CC'),
#  ('western', 'JJ'),
#  ('critics', 'NNS'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('release', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('received', 'VBD'),
#  ('downloadable', 'JJ'),
#  ('content', 'NN'),
#  (',', ','),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('an', 'DT'),
#  ('expanded', 'JJ'),
#  ('edition', 'NN'),
#  ('in', 'IN'),
#  ('November', 'NNP'),
#  ('of', 'IN'),
#  ('that', 'DT'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('was', 'VBD'),
#  ('also', 'RB'),
#  ('adapted', 'VBN'),
#  ('into', 'IN'),
#  ('manga', 'NN'),
#  ('and', 'CC'),
#  ('an', 'DT'),
#  ('original', 'JJ'),
#  ('video', 'NN'),
#  ('animation', 'NN'),
#  ('series', 'NN'),
#  ('.', '.'),
#  ('Due', 'NNP'),
#  ('to', 'TO'),
#  ('low', 'JJ'),
#  ('sales', 'NNS'),
#  ('of', 'IN'),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('II', 'NNP'),
#  (',', ','),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('III', 'NNP'),
#  ('was', 'VBD'),
#  ('not', 'RB'),
#  ('localized', 'VBN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('a', 'DT'),
#  ('fan', 'NN'),
#  ('translation', 'NN'),
#  ('compatible', 'JJ'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ("'s", 'POS'),
#  ('expanded', 'JJ'),
#  ('edition', 'NN'),
#  ('was', 'VBD'),
#  ('released', 'VBN'),
#  ('in', 'IN'),
#  ('2014', 'CD'),
#  ('.', '.'),
#  ('Media.Vision', 'NNP'),
#  ('would', 'MD'),
#  ('return', 'VB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('franchise', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('development', 'NN'),
#  ('of', 'IN'),
#  ('Valkyria', 'NNP'),
#  (':', ':'),
#  ('Azure', 'NN'),
#  ('Revolution', 'NNP'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('PlayStation', 'NNP'),
#  ('4', 'CD'),
#  ('.', '.'),
#  ('=', 'VB'),
#  ('=', 'JJ'),
#  ('Gameplay', 'NNP'),
#  ('=', 'NNP'),
#  ('=', 'NNP'),
#  ('As', 'IN'),
#  ('with', 'IN'),
#  ('previous', 'JJ'),
#  ('Valkyira', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('games', 'NNS'),
#  (',', ','),
#  ('Valkyria', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('III', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('tactical', 'JJ'),
#  ('role', 'NN'),
#  ('@', 'SYM'),
#  ('-', ':'),
#  ('@', 'JJ'),
#  ('playing', 'NN'),
#  ('game', 'NN'),
#  ('where', 'WRB'),
#  ('players', 'NNS'),
#  ('take', 'VBP'),
#  ('control', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('military', 'JJ'),
#  ('unit', 'NN'),
#  ('and', 'CC'),
#  ('take', 'VB'),
#  ('part', 'NN'),
#  ('in', 'IN'),
#  ('missions', 'NNS'),
#  ('against', 'IN'),
#  ('enemy', 'NN'),
#  ('forces', 'NNS'),
#  ('.', '.'),
#  ('Stories', 'NNS'),
#  ('are', 'VBP'),
#  ('told', 'VBN'),
#  ('through', 'IN'),
#  ('comic', 'JJ'),
#  ('book', 'NN'),
#  ('@', 'NNP'),
#  ('-', ':'),
#  ('@', 'NN'),
#  ('like', 'IN'),
#  ('panels', 'NNS'),
#  ('with', 'IN'),
#  ('animated', 'JJ'),
#  ('character', 'NN'),
#  ('portraits', 'NNS'),
#  (',', ','),
#  ('with', 'IN'),
#  ('characters', 'NNS'),
#  ('speaking', 'VBG'),
#  ('partially', 'RB'),
#  ('through', 'IN'),
#  ('voiced', 'VBN'),
#  ('speech', 'NN'),
#  ('bubbles', 'NNS'),
#  ('and', 'CC'),
#  ('partially', 'RB'),
#  ('through', 'IN'),
#  ('unvoiced', 'JJ'),
#  ('text', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('player', 'NN'),
#  ('progresses', 'VBZ'),
#  ('through', 'IN'),
#  ('a', 'DT'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('linear', 'JJ'),
#  ('missions', 'NNS'),
#  (',', ','),
#  ('gradually', 'RB'),
#  ('unlocked', 'JJ'),
#  ('as', 'IN'),
#  ('maps', 'NNS'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('freely', 'RB'),
#  ('scanned', 'VBN'),
#  ('through', 'IN'),
#  ('and', 'CC'),
#  ('replayed', 'VBN'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('unlocked', 'JJ'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('route', 'NN'),
#  ('to', 'TO'),
#  ('each', 'DT'),
#  ('story', 'NN'),
#  ('location', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('map', 'NN'),
#  ('varies', 'VBZ'),
#  ('depending', 'VBG'),
#  ('on', 'IN'),
#  ('an', 'DT'),
#  ('individual', 'JJ'),
#  ('player', 'NN'),
#  ("'s", 'POS'),
#  ('approach', 'NN'),
#  (':', ':'),
#  ('when', 'WRB'),
#  ('one', 'CD'),
#  ('option', 'NN'),
#  ('is', 'VBZ'),
#  ('selected', 'VBN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('is', 'VBZ'),
#  ('sealed', 'VBN'),
#  ('off', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('player', 'NN'),
#  ('.', '.'),
#  ('Outside', 'JJ'),
#  ('missions', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('player', 'NN'),
#  ('characters', 'NNS'),
#  ('rest', 'VBP'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('camp', 'NN'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('units', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('customized', 'VBN'),
#  ('and', 'CC'),
#  ('character', 'JJ'),
#  ('growth', 'NN'),
#  ('occurs', 'VBZ'),
#  ('.', '.'),
#  ('Alongside', 'IN'),
#  ('the', 'DT'),
#  ('main', 'JJ'),
#  ('story', 'NN'),
#  ('missions', 'NNS'),
#  ('are', 'VBP'),
#  ('character', 'JJ'),
#  ('@', 'NNP'),
#  ('-', ':'),
#  ('@', 'NN'),
#  ('specific', 'JJ'),
#  ('sub', 'JJ'),
#  ('missions', 'NNS'),
#  ('relating', 'VBG'),
#  ('to', 'TO'),
#  ('different', 'JJ'),
#  ('squad', 'JJ'),
#  ('members', 'NNS'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ("'s", 'POS'),
#  ('completion', 'NN'),
#  (',', ','),
#  ('additional', 'JJ'),
#  ('episodes', 'NNS'),
#  ('are', 'VBP'),
#  ('unlocked', 'JJ'),
#  (',', ','),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('them', 'PRP'),
#  ('having', 'VBG'),
#  ('a', 'DT'),
#  ('higher', 'JJR'),
#  ('difficulty', 'NN'),
#  ('than', 'IN'),
#  ('those', 'DT'),
#  ('found', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('rest', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('are', 'VBP'),
#  ('also', 'RB'),
#  ('love', 'JJ'),
#  ('simulation', 'NN'),
#  ('elements', 'NNS'),
#  ('related', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ("'s", 'POS'),
#  ('two', 'CD'),
#  ('main', 'JJ'),
#  ('heroines', 'NNS'),
#  (',', ','),
#  ('although', 'IN'),
#  ('they', 'PRP'),
#  ('take', 'VBP'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('minor', 'JJ'),
#  ('role', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('game', 'NN'),
#  ("'s", 'POS'),
#  ('battle', 'NN'),
#  ('system', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('BliTZ', 'NNP'),
#  ('system', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('carried', 'VBN'),
#  ('over', 'IN'),
#  ('directly', 'RB'),
#  ('from', 'IN'),
#  ('Valkyira', 'NNP'),
#  ('Chronicles', 'NNP'),
#  ('.', '.'),
#  ('During', 'IN'),
#  ('missions', 'NNS'),
#  (',', ','),
#  ('players', 'NNS'),
#  ('select', 'VBP'),
#  ('each', 'DT'),
#  ('unit', 'NN'),
#  ('using', 'VBG'),
#  ('a', 'DT'),
#  ('top', 'JJ'),
#  ('@', 'NN'),
#  ('-', ':'),
#  ('@', 'CC'),
#  ('down', 'IN'),
#  ('perspective', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('battlefield', 'NN'),
#  ('map', 'NN'),
#  (':', ':'),
#  ('once', 'RB'),
#  ('a', 'DT'),
#  ('character', 'NN'),
#  ('is', 'VBZ'),
#  ('selected', 'VBN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('player', 'NN'),
#  ('moves', 'VBZ'),
#  ('the', 'DT'),
#  ('character', 'NN'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('battlefield', 'NN'),
#  ('in', 'IN'),
#  ('third', 'JJ'),
#  ('@', 'NNP'),
#  ('-', ':'),
#  ('@', 'JJ'),
#  ('person', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('character', 'NN'),
#  ('can', 'MD'),
#  ('only', 'RB'),
#  ('act', 'VB'),
#  ('once', 'RB'),
#  ('per', 'IN'),
#  ('@', 'NNP'),
#  ('-', ':'),
#  ('@', 'NN'),
#  ('turn', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('characters', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('granted', 'VBN'),
#  ('multiple', 'JJ'),
#  ('turns', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('expense', 'NN'),
#  ('of', 'IN'),
#  ('other', 'JJ'),
#  ('characters', 'NNS'),
#  ("'", 'POS'),
#  ('turns', 'NNS'),
#  ('.', '.'),
#  ('Each', 'DT'),
#  ('character', 'NN'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('field', 'NN'),
#  ('and', 'CC'),
#  ('distance', 'NN'),
#  ('of', 'IN'),
#  ('movement', 'NN'),
#  ('limited', 'VBN'),
#  ('by', 'IN'),
#  ('their', 'PRP$'),
#  ('Action', 'NNP'),
#  ('Gauge', 'NNP'),
#  ('.', '.'),
#  ('Up', 'NNP'),
#  ('to', 'TO'),
#  ('nine', 'CD'),
#  ('characters', 'NNS'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('assigned', 'VBN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('single', 'JJ'),
#  ('mission', 'NN'),
#  ('.', '.'),
#  ('During', 'IN'),
#  ('gameplay', 'NN'),
#  (',', ','),
#  ('characters', 'NNS'),
#  ('will', 'MD'),
#  ('call', 'VB'),
#  ('out', 'RP'),
#  ('if', 'IN'),
#  ('something', 'NN'),
#  ('happens', 'VBZ'),
#  ('to', 'TO'),
#  ('them', 'PRP'),
#  (',', ','),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('their', 'PRP$'),
#  ('health', 'NN'),
#  ('points', 'NNS'),
#  ('(', '('),
#  ('HP', 'NNP'),
#  (')', ')'),
#  ('getting', 'VBG'),
#  ('low', 'JJ'),
#  ('or', 'CC'),
#  ('being', 'VBG'),
#  ('knocked', 'VBN'),
#  ('out', 'RP'),
#  ('by', 'IN'),
#  ('enemy', 'NN'),
#  ('attacks', 'NNS'),
#  ('.', '.'),
#  ('Each', 'DT'),
#  ('character', 'NN'),
#  ('has', 'VBZ'),
#  ('specific', 'JJ'),
#  ('``', '``'),
#  ('Potentials', 'NNS'),
#  ('``', '``'),
#  (',', ','),
#  ('skills', 'VBZ'),
#  ('unique', 'JJ'),
#  ('to', 'TO'),
#  ('each', 'DT'),
#  ('character', 'NN'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('are', 'VBP'),
#  ('divided', 'VBN'),
#  ('into', 'IN'),
#  ('``', '``'),
#  ('Personal', 'NNP'),
#  ('Potential', 'NNP'),
#  ('``', '``'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('are', 'VBP'),
#  ('innate', 'JJ'),
#  ('skills', 'NNS'),
#  ('that', 'WDT'),
#  ('remain', 'VBP'),
#  ('unaltered', 'JJ'),
#  ('unless', 'IN'),
#  ('otherwise', 'RB'),
#  ('dictated', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('story', 'NN'),
#  ('and', 'CC'),
#  ('can', 'MD'),
#  ('either', 'VB'),
#  ('help', 'NN'),
#  ('or', 'CC'),
#  ('impede', 'VB'),
#  ('a', 'DT'),
#  ('character', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('``', '``'),
#  ('Battle', 'NNP'),
#  ('Potentials', 'NNP'),
#  ('``', '``'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('are', 'VBP'),
#  ('grown', 'VBN'),
#  ('throughout', 'IN'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ('and', 'CC'),
#  ('always', 'RB'),
#  ('grant', 'VB'),
#  ('boons', 'NNS'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('character', 'NN'),
#  ('.', '.'),
#  ('To', 'TO'),
#  ('learn', 'VB'),
#  ('Battle', 'NNP'),
#  ('Potentials', 'NNP'),
#  (',', ','),
#  ('each', 'DT'),
#  ('character', 'NN'),
#  ('has', 'VBZ'),
#  ('a', 'DT'),
#  ('unique', 'JJ'),
#  ('``', '``'),
#  ('Masters', 'NNS'),
#  ('Table', 'JJ'),
#  ('``', '``'),
#  (',', ','),
#  ('a', 'DT'),
#  ('grid', 'NN'),
#  ('@', 'SYM'),
#  ('-', ':'),
#  ('@', 'NN'),
#  ('based', 'VBN'),
#  ('skill', 'NN'),
#  ('table', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('used', 'VBN'),
#  ('to', 'TO'),
#  ('acquire', 'VB'),
#  ('and', 'CC'),
#  ('link', 'VB'),
#  ('different', 'JJ'),
#  ('skills', 'NNS'),
#  ('.', '.'),
#  ('Characters', 'NNS'),
#  ('also', 'RB'),
#  ('have', 'VBP'),
#  ('Special', 'JJ'),
#  ('Abilities', 'NNS'),
#  ('that', 'WDT'),
#  ('grant', 'VBP'),
#  ('them', 'PRP'),
#  ('temporary', 'JJ'),
#  ('boosts', 'NNS'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('battlefield', 'NN'),
#  (':', ':'),
#  ('Kurt', 'NNP'),
#  ('can', 'MD'),
#  ('activate', 'VB'),
#  ('``', '``'),
#  ('Direct', 'NNP'),
#  ('Command', 'NNP'),
#  ('``', '``'),
#  ('and', 'CC'),
#  ('move', 'VB'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('battlefield', 'NN'),
#  ('without', 'IN'),
#  ('depleting', 'VBG'),
#  ('his', 'PRP$'),
#  ('Action', 'NN'),
#  ('Point', 'NNP'),
#  ('gauge', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('character', 'NN'),
#  ('Reila', 'NNP'),
#  ('can', 'MD'),
#  ('shift', 'VB'),
#  ('into', 'IN'),
#  ('her', 'PRP$'),
#  ('``', '``'),
#  ('Valkyria', 'NNP'),
#  ('Form', 'NNP'),
#  ('``', '``'),
#  ('and', 'CC'),
#  ('become', 'VB'),
#  ('invincible', 'JJ'),
#  (',', ','),
#  ('while', 'IN'),
#  ('Imca', 'NNP'),
#  ('can', 'MD'),
#  ('target', 'VB'),
#  ('multiple', 'JJ'),
#  ('enemy', 'JJ'),
#  ('units', 'NNS'),
#  ('with', 'IN'),
#  ('her', 'PRP$'),
#  ('heavy', 'JJ'),
#  ('weapon', 'NN'),
#  ('.', '.'),
#  ('Troops', 'NNS'),
#  ('are', 'VBP'),
#  ('divided', 'VBN'),
#  ('into', 'IN'),
#  ('five', 'CD'),
#  ('classes', 'NNS'),
#  (':', ':'),
#  ('Scouts', 'NNP'),
#  (',', ','),
#  ('Shocktroopers', 'NNP'),
#  (',', ','),
#  ('Engineers', 'NNP'),
#  (',', ','),
#  ('Lancers', 'NNP'),
#  ('and', 'CC'),
#  ('Armored', 'NNP'),
#  ('Soldier', 'NNP'),
#  ('.', '.'),
#  ('Troopers', 'NNS'),
#  ('can', 'MD'),
#  ('switch', 'VB'),
#  ('classes', 'NNS'),
#  ('by', 'IN'),
#  ('changing', 'VBG'),
#  ('their', 'PRP$'),
#  ('assigned', 'VBN'),
#  ('weapon', 'NN'),
#  ('.', '.'),
#  ('Changing', 'VBG'),
#  ('class', 'NN'),
#  ('does', 'VBZ'),
#  ('not', 'RB'),
#  ('greatly', 'RB'),
#  ('affect', 'VBP'),
#  ('the', 'DT'),
#  ('stats', 'NNS'),
#  ('gained', 'VBD'),
#  ('while', 'IN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('previous', 'JJ'),
#  ('class', 'NN'),
#  ('.', '.'),
#  ('With', 'IN'),
#  ('victory', 'NN'),
#  ('in', 'IN'),
#  ('battle', 'NN'),
#  (',', ','),
#  ('experience', 'NN'),
#  ('points', 'NNS'),
#  ('are', 'VBP'),
#  ('awarded', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('squad', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('are', 'VBP'),
#  ('distributed', 'VBN'),
#  ('into', 'IN'),
#  ('five', 'CD'),
#  ('different', 'JJ'),
#  ('attributes', 'NNS'),
#  ('shared', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('entire', 'JJ'),
#  ('squad', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('feature', 'NN'),
#  ('differing', 'VBG'),
#  ('from', 'IN'),
#  ('early', 'JJ'),
#  ('games', 'NNS'),
#  ("'", 'POS'),
#  ('method', 'NN'),
#  ('of', 'IN'),
#  ('distributing', 'VBG'),
#  ('to', 'TO'),
#  ('different', 'JJ'),
#  ('unit', 'NN'),
#  ('types', 'NNS'),
#  ('.', '.'),
#  ('=', 'NN'),
#  ('=', 'NN'),
#  ('Plot', 'NNP'),
#  ('=', 'NNP'),
#  ('=', 'VBD'),
#  ('The', 'DT'),
#  ('game', 'NN'),
#  ('takes', 'VBZ'),
#  ('place', 'NN'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('Second', 'NNP'),
#  ('Europan', 'NNP'),
#  ('War', 'NNP'),
#  ('.', '.'),
#  ('Gallian', 'JJ'),
#  ('Army', 'NNP'),
#  ('Squad', 'NNP'),
#  ('422', 'CD'),
#  (',', ','),
#  ('also', 'RB'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('``', '``'),
#  ('The', 'DT'),
#  ('Nameless', 'NNP'),
#  ('``', '``'),
#  (',', ','),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('penal', 'JJ'),
#  ('military', 'JJ'),
#  ('unit', 'NN'),
#  ('composed', 'VBD'),
#  ('of', 'IN'),
#  ('criminals', 'NNS'),
#  (',', ','),
#  ('foreign', 'JJ'),
#  ('deserters', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('military', 'JJ'),
#  ('offenders', 'NNS'),
#  ('whose', 'WP$'),
#  ('real', 'JJ'),
#  ('names', 'NNS'),
#  ('are', 'VBP'),
#  ('erased', 'VBN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('records', 'NNS'),
#  ('and', 'CC'),
#  ('thereon', 'NN'),
#  ('officially', 'RB'),
#  ('referred', 'VBN'),
#  ('to', 'TO'),
#  ('by', 'IN'),
#  ('numbers', 'NNS'),
#  ('.', '.'),
#  ('Ordered', 'VBN'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ...]

# %%
lemmatizer = WordNetLemmatizer()
dataset = [lemmatizer.lemmatize(word, pos=get_wordnet_pos(pos)) for word, pos in tagged_dataset]
print(dataset[5000:5100])
# Out:
# ['the', 'governor', 'agree', 'to', 'three', 'provision', ':', 'The', 'governor', 'would', 'take', 'possession', 'of', 'the', 'arsenal', 'in', 'the', 'name', 'of', 'the', 'United', 'States', '.', 'The', 'soldier', 'would', 'be', 'allow', 'safe', 'passage', 'in', 'any', 'direction', 'carry', 'any', 'personal', 'and', 'public', 'property', 'besides', 'munition', 'of', 'war', '.', 'The', 'soldier', 'would', 'be', 'allow', 'to', 'march', 'away', 'a', 'men', 'leave', 'under', 'order', ',', 'not', 'a', 'conquer', 'and', 'surrender', 'soldier', '.', 'On', 'the', 'morning', 'of', 'February', '8', ',', '1861', ',', 'Rector', 'and', 'Totten', 'sign', 'an', 'agreement', 'place', 'the', 'arsenal', 'in', 'the', 'hand', 'of', 'state', 'official', '.', 'That', 'afternoon', ',', 'the', 'citizen', 'militia', 'march', 'to', 'the', 'arsenal']

# %%
verb_counts = Counter([word for i, word in enumerate(dataset) if tagged_dataset[i][1].startswith('V') and re.match(r'^[a-zA-Z]+$', word)])
most_common_verbs = list(zip(*verb_counts.most_common(50)))[0]

# %%
verb_counts
# Out:
# Counter({'be': 1254523,
#          'have': 303680,
#          'make': 65781,
#          'include': 62390,
#          'use': 54574,
#          'do': 53249,
#          'become': 51174,
#          'take': 50655,
#          'write': 39816,
#          'say': 39421,
#          'begin': 35516,
#          'give': 34700,
#          'know': 32130,
#          'play': 32126,
#          'find': 31777,
#          'call': 30306,
#          'go': 27409,
#          'release': 27050,
#          'win': 26159,
#          'lead': 25546,
#          'receive': 25472,
#          'follow': 25114,
#          'leave': 24454,
#          'come': 24204,
#          'remain': 21561,
#          'continue': 21171,
#          'describe': 21150,
#          'move': 21037,
#          'work': 20969,
#          'hold': 20390,
#          'appear': 19166,
#          'return': 19157,
#          'see': 18987,
#          'build': 18548,
#          'produce': 17660,
#          'create': 17350,
#          'reach': 17269,
#          'provide': 17041,
#          'base': 17006,
#          'allow': 16849,
#          'name': 16552,
#          'serve': 16378,
#          'run': 16256,
#          'show': 16117,
#          'consider': 15937,
#          'feature': 15891,
#          'state': 15667,
#          'start': 15513,
#          'get': 15401,
#          'record': 15176,
#          'develop': 15047,
#          'lose': 14817,
#          'form': 14641,
#          'cause': 14362,
#          'set': 14053,
#          'perform': 13997,
#          'kill': 13989,
#          'end': 13768,
#          'think': 12897,
#          'sell': 12626,
#          'bring': 12508,
#          'publish': 12382,
#          'want': 12374,
#          'note': 12310,
#          'turn': 12157,
#          'believe': 12146,
#          'die': 12079,
#          'add': 11985,
#          'help': 11883,
#          'pass': 11846,
#          'send': 11812,
#          'join': 11750,
#          'open': 11688,
#          'establish': 11633,
#          'tell': 11316,
#          'meet': 11129,
#          'contain': 11083,
#          'complete': 10914,
#          'decide': 10834,
#          'support': 10805,
#          'score': 10774,
#          'increase': 10761,
#          'live': 10644,
#          'report': 10602,
#          'carry': 10508,
#          'suggest': 10446,
#          'According': 10419,
#          'replace': 10243,
#          'announce': 9808,
#          'enter': 9752,
#          'involve': 9574,
#          'try': 9491,
#          'felt': 9420,
#          'keep': 9294,
#          'place': 9119,
#          'finish': 9030,
#          'ask': 9007,
#          'locate': 8979,
#          'claim': 8969,
#          'occur': 8810,
#          'grow': 8787,
#          'require': 8731,
#          'break': 8646,
#          'put': 8625,
#          'force': 8471,
#          'change': 8443,
#          'arrive': 8381,
#          'result': 8371,
#          'offer': 7980,
#          'design': 7960,
#          'bear': 7918,
#          'defeat': 7879,
#          'attack': 7823,
#          'represent': 7656,
#          'saw': 7616,
#          'spend': 7615,
#          'direct': 7607,
#          'praise': 7602,
#          'destroy': 7573,
#          'sign': 7568,
#          'mean': 7420,
#          'cover': 7315,
#          'look': 7240,
#          'introduce': 7212,
#          'raise': 7201,
#          'fail': 7177,
#          'choose': 7115,
#          'attempt': 7088,
#          'need': 6931,
#          'agree': 6911,
#          'Following': 6882,
#          'remove': 6732,
#          'consist': 6726,
#          'capture': 6708,
#          'reveal': 6621,
#          'pay': 6542,
#          'order': 6501,
#          'refer': 6468,
#          'fight': 6439,
#          'attend': 6401,
#          'reduce': 6375,
#          'operate': 6340,
#          'discover': 6338,
#          'maintain': 6323,
#          'draw': 6305,
#          'explain': 6283,
#          'suffer': 6261,
#          'travel': 6249,
#          'exist': 6175,
#          'extend': 6174,
#          'plan': 6130,
#          'stand': 6082,
#          'earn': 6073,
#          'fly': 6052,
#          'seek': 6022,
#          'accord': 6012,
#          'accept': 6012,
#          'cross': 5964,
#          'face': 5899,
#          'compare': 5893,
#          'shoot': 5837,
#          'promote': 5836,
#          'hit': 5827,
#          'act': 5771,
#          'propose': 5742,
#          'marry': 5711,
#          'argue': 5698,
#          'appoint': 5632,
#          'gain': 5575,
#          'present': 5575,
#          'manage': 5520,
#          'rank': 5476,
#          'launch': 5474,
#          'issue': 5457,
#          'intend': 5454,
#          'learn': 5391,
#          'award': 5354,
#          'prevent': 5315,
#          'damage': 5284,
#          'visit': 5273,
#          'seem': 5203,
#          'refuse': 5180,
#          'indicate': 5162,
#          'stop': 5161,
#          'drop': 5100,
#          'compose': 5087,
#          'estimate': 5087,
#          'conduct': 5085,
#          'declare': 5044,
#          'regard': 5006,
#          'comment': 4998,
#          'protect': 4992,
#          'fall': 4972,
#          'select': 4948,
#          'mark': 4947,
#          'participate': 4946,
#          'expect': 4938,
#          'list': 4923,
#          'prove': 4922,
#          'drive': 4912,
#          'construct': 4883,
#          'close': 4830,
#          'survive': 4779,
#          'improve': 4765,
#          'wear': 4752,
#          'achieve': 4749,
#          'fire': 4739,
#          'peak': 4723,
#          'conclude': 4689,
#          'express': 4601,
#          'speak': 4589,
#          'focus': 4581,
#          'identify': 4568,
#          'sing': 4560,
#          'connect': 4547,
#          'control': 4535,
#          'assign': 4534,
#          'watch': 4519,
#          'determine': 4465,
#          'strike': 4464,
#          'fell': 4437,
#          'inspire': 4434,
#          'stay': 4428,
#          'surround': 4423,
#          'observe': 4414,
#          'cut': 4409,
#          'hear': 4377,
#          'lay': 4340,
#          'affect': 4299,
#          'associate': 4294,
#          'expand': 4274,
#          'transfer': 4268,
#          'own': 4231,
#          'relate': 4229,
#          'film': 4225,
#          'read': 4163,
#          'elect': 4130,
#          'avoid': 4110,
#          'miss': 4028,
#          'head': 3988,
#          'defend': 3937,
#          'oppose': 3909,
#          'rise': 3906,
#          'prepare': 3867,
#          'accompany': 3855,
#          'engage': 3839,
#          'found': 3839,
#          'air': 3827,
#          'cite': 3815,
#          'star': 3806,
#          'confirm': 3784,
#          'approach': 3779,
#          'retain': 3764,
#          'contribute': 3751,
#          'influence': 3738,
#          'save': 3730,
#          'acquire': 3722,
#          'study': 3680,
#          'divide': 3662,
#          'feel': 3656,
#          'criticize': 3637,
#          'buy': 3635,
#          'adopt': 3634,
#          'abandon': 3631,
#          'compete': 3624,
#          'date': 3598,
#          'secure': 3564,
#          'land': 3561,
#          'purchase': 3557,
#          'depict': 3486,
#          'discuss': 3484,
#          'escape': 3476,
#          'organize': 3476,
#          'grant': 3467,
#          'catch': 3461,
#          'view': 3448,
#          'title': 3444,
#          'throw': 3441,
#          'advance': 3413,
#          'obtain': 3402,
#          'enjoy': 3392,
#          'collect': 3371,
#          'recognize': 3364,
#          'debut': 3337,
#          'deliver': 3327,
#          'define': 3326,
#          'withdraw': 3312,
#          'retire': 3290,
#          'fill': 3273,
#          'reject': 3265,
#          'nominate': 3253,
#          'portray': 3250,
#          'apply': 3241,
#          'host': 3225,
#          'mention': 3217,
#          'incorporate': 3216,
#          'reflect': 3161,
#          'designate': 3160,
#          'succeed': 3150,
#          'occupy': 3147,
#          'weaken': 3074,
#          'convert': 3068,
#          'combine': 3067,
#          'respond': 3055,
#          'employ': 3026,
#          'lie': 3011,
#          'cast': 3003,
#          'train': 2995,
#          'love': 2983,
#          'assume': 2970,
#          'threaten': 2970,
#          'happen': 2955,
#          'decline': 2941,
#          'beat': 2938,
#          'lack': 2924,
#          'emerge': 2906,
#          'fit': 2901,
#          'command': 2899,
#          'attract': 2895,
#          'admit': 2893,
#          'limit': 2876,
#          'hire': 2871,
#          'recover': 2861,
#          'don': 2848,
#          's': 2832,
#          'teach': 2832,
#          'last': 2821,
#          're': 2816,
#          'settle': 2815,
#          'sit': 2813,
#          'experience': 2813,
#          'assist': 2809,
#          'range': 2771,
#          'hop': 2771,
#          'restore': 2768,
#          'sail': 2758,
#          'share': 2757,
#          'encourage': 2732,
#          'recall': 2728,
#          'vote': 2687,
#          'push': 2656,
#          'rule': 2643,
#          'convince': 2639,
#          'commission': 2621,
#          'ensure': 2614,
#          'approve': 2603,
#          'measure': 2586,
#          'mount': 2565,
#          'pick': 2545,
#          'display': 2542,
#          'separate': 2540,
#          'wound': 2537,
#          'generate': 2525,
#          'like': 2523,
#          'charge': 2518,
#          'adapt': 2506,
#          'point': 2503,
#          'let': 2502,
#          'arrange': 2487,
#          'tie': 2460,
#          'test': 2459,
#          'deny': 2458,
#          'sink': 2454,
#          'walk': 2450,
#          'recommend': 2437,
#          'commit': 2425,
#          'pursue': 2408,
#          'link': 2406,
#          'invite': 2401,
#          'shape': 2396,
#          'credit': 2367,
#          'arrest': 2363,
#          'realize': 2361,
#          'deal': 2346,
#          'talk': 2344,
#          'pull': 2340,
#          'inform': 2321,
#          'rat': 2316,
#          'treat': 2308,
#          'post': 2298,
#          'concern': 2298,
#          'eat': 2283,
#          'rename': 2278,
#          'attribute': 2275,
#          'schedule': 2271,
#          'tour': 2268,
#          'depend': 2262,
#          'derive': 2259,
#          'demonstrate': 2258,
#          'bury': 2246,
#          'dedicate': 2245,
#          'encounter': 2236,
#          'request': 2234,
#          'eliminate': 2217,
#          'dominate': 2209,
#          'vary': 2202,
#          'cancel': 2201,
#          'tend': 2196,
#          'burn': 2193,
#          'accuse': 2184,
#          'explore': 2145,
#          'challenge': 2139,
#          'preserve': 2127,
#          'qualify': 2113,
#          'investigate': 2113,
#          'prompt': 2112,
#          'flee': 2095,
#          'entitle': 2085,
#          'track': 2082,
#          'comprise': 2079,
#          'handle': 2072,
#          'wait': 2069,
#          'celebrate': 2067,
#          'demand': 2062,
#          'chart': 2062,
#          'understand': 2059,
#          'delay': 2047,
#          'resign': 2042,
#          'strengthen': 2036,
#          'instal': 2017,
#          'sound': 2015,
#          'execute': 2007,
#          'paint': 1990,
#          'classify': 1986,
#          'equip': 1985,
#          'depart': 1980,
#          'dismiss': 1978,
#          'struggle': 1976,
#          'attach': 1968,
#          'arm': 1966,
#          'review': 1962,
#          'back': 1960,
#          'sustain': 1945,
#          'distribute': 1944,
#          'split': 1903,
#          'address': 1897,
#          'didn': 1896,
#          'aim': 1891,
#          'warn': 1877,
#          'pitch': 1874,
#          'deploy': 1872,
#          'flood': 1872,
#          'resume': 1867,
#          'intensify': 1828,
#          'enable': 1819,
#          'steal': 1817,
#          'proceed': 1814,
#          'certify': 1810,
#          'attain': 1810,
#          'broadcast': 1806,
#          'spread': 1803,
#          'prefer': 1798,
#          'distinguish': 1794,
#          'injure': 1791,
#          'submit': 1773,
#          'graduate': 1772,
#          'repeat': 1762,
#          'clear': 1761,
#          'belong': 1757,
#          'wish': 1751,
#          'supply': 1746,
#          'gather': 1743,
#          'rescue': 1739,
#          'deem': 1738,
#          'seize': 1712,
#          'age': 1711,
#          'remember': 1710,
#          'expose': 1708,
#          'hand': 1700,
#          'match': 1689,
#          'transport': 1675,
#          'resemble': 1672,
#          'dissipate': 1661,
#          'insist': 1656,
#          'surrender': 1649,
#          'top': 1639,
#          'premier': 1633,
#          'predict': 1624,
#          'bat': 1611,
#          'criticise': 1606,
#          'promise': 1594,
#          'acknowledge': 1588,
#          'evolve': 1580,
#          'voice': 1579,
#          'block': 1577,
#          'question': 1573,
#          'upgrade': 1570,
#          'undertake': 1568,
#          'evacuate': 1567,
#          'originate': 1557,
#          'hunt': 1553,
#          'file': 1552,
#          'retreat': 1545,
#          'search': 1543,
#          'shift': 1542,
#          'progress': 1539,
#          'permit': 1520,
#          'recognise': 1519,
#          'assert': 1514,
#          'rely': 1512,
#          'listen': 1503,
#          'modify': 1503,
#          'rebuild': 1502,
#          'fund': 1491,
#          'breed': 1488,
#          'hide': 1480,
#          'persuade': 1480,
#          'decrease': 1474,
#          'climb': 1472,
#          'possess': 1468,
#          'aid': 1467,
#          'reinforce': 1457,
#          'resolve': 1451,
#          'escort': 1448,
#          'alter': 1448,
#          'implement': 1447,
#          'trade': 1446,
#          'characterize': 1443,
#          'weigh': 1440,
#          'edit': 1440,
#          'suppose': 1430,
#          'appeal': 1415,
#          'feed': 1415,
#          'concentrate': 1410,
#          'examine': 1409,
#          'advise': 1406,
#          'collapse': 1402,
#          'translate': 1399,
#          'suspend': 1399,
#          'highlight': 1398,
#          'merge': 1396,
#          'recruit': 1386,
#          'initiate': 1379,
#          'cease': 1349,
#          'restrict': 1349,
#          'exceed': 1344,
#          'remark': 1343,
#          'interpret': 1336,
#          'knock': 1335,
#          'enlist': 1330,
#          'fear': 1328,
#          'print': 1318,
#          'blow': 1316,
#          'switch': 1314,
#          'render': 1308,
#          'average': 1303,
#          'flow': 1298,
#          'wing': 1291,
#          'organise': 1289,
#          'transform': 1285,
#          'negotiate': 1282,
#          'spot': 1280,
#          'situate': 1277,
#          'rush': 1275,
#          'relieve': 1273,
#          'ship': 1273,
#          'illustrate': 1268,
#          'donate': 1268,
#          'ignore': 1268,
#          'ban': 1264,
#          'detect': 1263,
#          'cost': 1260,
#          'differ': 1259,
#          'dress': 1259,
#          'regain': 1252,
#          'commence': 1251,
#          'precede': 1250,
#          'confront': 1250,
#          'gross': 1248,
#          'urge': 1248,
#          'invade': 1239,
#          'hang': 1239,
#          'register': 1236,
#          'exhibit': 1231,
#          'emphasize': 1231,
#          'march': 1226,
#          'undergo': 1224,
#          'erect': 1223,
#          'disappear': 1221,
#          'Having': 1221,
#          'Is': 1221,
#          'assemble': 1213,
#          'relocate': 1212,
#          'target': 1210,
#          'arise': 1208,
#          'demolish': 1205,
#          'contact': 1203,
#          'complain': 1199,
#          'blame': 1195,
#          'impose': 1195,
#          'power': 1190,
#          'reply': 1188,
#          'collaborate': 1184,
#          'repair': 1175,
#          'dance': 1173,
#          'co': 1171,
#          'govern': 1170,
#          'draft': 1157,
#          'absorb': 1155,
#          'impress': 1153,
#          'descend': 1145,
#          'slow': 1143,
#          'crash': 1138,
#          'owe': 1137,
#          'total': 1135,
#          'consume': 1125,
#          'notice': 1122,
#          'exclude': 1114,
#          'lift': 1109,
#          'jump': 1107,
#          'witness': 1106,
#          'commemorate': 1100,
#          'advocate': 1097,
#          'label': 1097,
#          'pose': 1092,
#          'King': 1089,
#          'honor': 1088,
#          'quote': 1083,
#          'fix': 1071,
#          'dub': 1068,
#          'conceive': 1066,
#          'murder': 1063,
#          'embark': 1061,
#          'mix': 1059,
#          'accommodate': 1059,
#          'curve': 1058,
#          'garner': 1054,
#          'oversee': 1054,
#          'touch': 1051,
#          'allege': 1047,
#          'renew': 1046,
#          'load': 1045,
#          'educate': 1043,
#          'intersect': 1040,
#          'bowl': 1036,
#          'displace': 1035,
#          'store': 1032,
#          'rest': 1031,
#          'station': 1031,
#          'surpass': 1029,
#          'revive': 1024,
#          'enhance': 1024,
#          'kick': 1024,
#          'wind': 1023,
#          'suspect': 1021,
#          'solve': 1018,
#          'sponsor': 1017,
#          'coach': 1012,
#          'devote': 1005,
#          'account': 1002,
#          'trap': 998,
#          'ten': 987,
#          'speculate': 979,
#          'compile': 971,
#          'step': 969,
#          'calculate': 966,
#          'light': 966,
#          'decorate': 965,
#          'manufacture': 964,
#          'press': 964,
#          'sentence': 963,
#          'condemn': 960,
#          'halt': 957,
#          'animate': 954,
#          'perceive': 952,
#          'realise': 948,
#          'inherit': 948,
#          'assess': 946,
#          'authorize': 945,
#          'proclaim': 945,
#          'lower': 944,
#          'round': 943,
#          'ensue': 938,
#          'inhabit': 937,
#          'isolate': 934,
#          'count': 933,
#          'document': 933,
#          'reverse': 933,
#          'bind': 930,
#          'roll': 929,
#          'recur': 928,
#          'span': 926,
#          'sleep': 925,
#          'react': 919,
#          'revise': 918,
#          'stag': 911,
#          'intercept': 909,
#          'resist': 908,
#          'free': 902,
#          'double': 900,
#          'favor': 898,
#          'imply': 898,
#          'guide': 897,
#          'task': 894,
#          'answer': 893,
#          'constitute': 888,
#          'stretch': 886,
#          'care': 882,
#          'satisfy': 882,
#          'instruct': 881,
#          'opine': 880,
#          'raid': 879,
#          'swim': 879,
#          'wash': 865,
#          'appreciate': 864,
#          'surprise': 857,
#          'scrap': 857,
#          'model': 852,
#          'scatter': 852,
#          'disband': 851,
#          'number': 849,
#          'rid': 848,
#          'sweep': 848,
#          'Writing': 847,
#          'Based': 844,
#          'disrupt': 840,
#          'center': 839,
#          'forget': 838,
#          'confuse': 834,
#          'trigger': 834,
#          'rejoin': 832,
#          'prohibit': 830,
#          'race': 829,
#          'strip': 828,
#          'overcome': 827,
#          'compliment': 826,
#          'opt': 825,
#          'convict': 825,
#          'inflict': 824,
#          'imprison': 824,
#          'drink': 821,
#          'administer': 821,
#          'chase': 821,
#          'reference': 820,
#          'wasn': 819,
#          'deteriorate': 819,
#          'culminate': 819,
#          'shut': 817,
#          'house': 816,
#          'benefit': 816,
#          'enforce': 815,
#          'position': 811,
#          'spawn': 810,
#          'conquer': 806,
#          'overlook': 806,
#          'reunite': 805,
#          'dissolve': 804,
#          'consult': 804,
#          'activate': 803,
#          'coincide': 801,
#          'correspond': 799,
#          'borrow': 797,
#          'guard': 797,
#          'dispatch': 794,
#          'anticipate': 794,
#          'orient': 790,
#          'terminate': 787,
#          'integrate': 786,
#          'communicate': 783,
#          'accelerate': 780,
#          'counter': 778,
#          'suit': 774,
#          'abolish': 773,
#          'doesn': 773,
#          'accomplish': 772,
#          'fee': 772,
#          'utilize': 770,
#          'induct': 770,
#          'dislike': 768,
#          'trace': 764,
#          'persist': 763,
#          'invest': 761,
#          'interact': 758,
#          'explode': 758,
#          'monitor': 757,
#          'drown': 757,
#          'interview': 756,
#          'convey': 756,
#          'screen': 750,
#          'interrupt': 749,
#          'project': 747,
#          'protest': 746,
#          'supervise': 744,
#          'home': 743,
#          'invent': 742,
#          'exploit': 741,
#          'yield': 738,
#          'concede': 738,
#          'endorse': 736,
#          'impact': 733,
#          'ride': 733,
#          'check': 729,
#          'exit': 728,
#          'violate': 727,
#          'penetrate': 725,
#          'reside': 724,
#          'facilitate': 723,
#          'exercise': 723,
#          'detail': 722,
#          'respect': 721,
#          'finance': 721,
#          'lock': 720,
#          'import': 716,
#          'judge': 713,
#          'rout': 712,
#          'bomb': 709,
#          'tear': 709,
#          'crown': 708,
#          'contest': 707,
#          'amount': 706,
#          'worry': 705,
#          'captain': 705,
#          'row': 704,
#          'theme': 702,
#          'contrast': 700,
#          'reserve': 699,
#          'remind': 697,
#          'accumulate': 696,
#          'dig': 693,
#          'summon': 691,
#          'stick': 690,
#          'discontinue': 689,
#          'enact': 688,
#          'al': 687,
#          'enrol': 685,
#          'float': 684,
#          'Beginning': 684,
#          'welcome': 684,
#          'bypass': 680,
#          'reform': 679,
#          'carve': 677,
#          'disagree': 676,
#          'embrace': 676,
#          'patrol': 672,
#          'allocate': 671,
#          'suppress': 671,
#          'justify': 670,
#          'adjust': 668,
#          'sue': 667,
#          'endure': 665,
#          'encompass': 664,
#          'debate': 663,
#          'admire': 663,
#          'side': 662,
#          'revolve': 660,
#          'dispute': 660,
#          'testify': 660,
#          'pave': 659,
#          'exchange': 658,
#          'expel': 657,
#          'reprise': 657,
#          'color': 655,
#          'retrieve': 654,
#          'elevate': 653,
#          'nickname': 652,
#          'port': 651,
#          'hurt': 649,
#          'rotate': 648,
#          'stem': 647,
#          'Let': 646,
#          'afford': 645,
#          'bombard': 645,
#          'unveil': 644,
#          'line': 644,
#          'denote': 643,
#          'object': 641,
#          'process': 641,
#          'experiment': 640,
#          'diagnose': 639,
#          'crush': 639,
#          'contract': 639,
#          'campaign': 639,
#          'size': 638,
#          'Using': 638,
#          'regulate': 637,
#          'devastate': 635,
#          'circulate': 632,
#          'specify': 629,
#          'shock': 627,
#          'Be': 626,
#          'assure': 625,
#          'assault': 625,
#          'coordinate': 624,
#          'guarantee': 623,
#          'disappoint': 620,
#          'term': 620,
#          'team': 618,
#          'audition': 616,
#          'provoke': 616,
#          'practice': 616,
#          'board': 614,
#          'extract': 614,
#          'diminish': 613,
#          'commend': 611,
#          'favour': 610,
#          'divert': 610,
#          'induce': 610,
#          'drain': 607,
#          'analyze': 607,
#          'confess': 606,
#          'transmit': 606,
#          'signal': 605,
#          'imagine': 604,
#          'license': 604,
#          'quit': 604,
#          'intervene': 601,
#          'deserve': 601,
#          'steer': 599,
#          'ring': 599,
#          'kiss': 599,
#          'echo': 595,
#          'seat': 593,
#          'widen': 593,
#          'submerge': 592,
#          'Love': 591,
#          'consolidate': 591,
#          'balance': 590,
#          'interfere': 590,
#          'seal': 588,
#          'shorten': 588,
#          'desire': 587,
#          'sport': 587,
#          'leak': 586,
#          'disperse': 586,
#          'spark': 586,
#          'pin': 585,
#          'bore': 583,
#          'reconstruct': 583,
#          'confine': 580,
#          'band': 579,
#          'complicate': 579,
#          'spin': 579,
#          'subject': 578,
#          'migrate': 577,
#          'wrestle': 577,
#          'drift': 576,
#          'parallel': 576,
#          'update': 576,
#          'pack': 574,
#          'supplement': 573,
#          'postpone': 573,
#          'ascend': 573,
#          'devise': 570,
#          'king': 570,
#          'plant': 569,
#          'dive': 567,
#          'reopen': 567,
#          'alternate': 566,
#          'ruin': 565,
#          'Are': 565,
#          'heat': 565,
#          'couldn': 561,
#          'Do': 561,
#          'evaluate': 561,
#          'couple': 560,
#          'steam': 558,
#          'greet': 553,
#          'lease': 553,
#          'tail': 553,
#          'function': 552,
#          'stress': 552,
#          'watershed': 552,
#          'kidnap': 552,
#          'excite': 551,
#          'expire': 549,
#          'anchor': 549,
#          'clean': 549,
#          'Flying': 548,
#          'overlap': 548,
#          'program': 548,
#          'please': 546,
#          'contend': 545,
#          'coin': 542,
#          'correct': 541,
#          'liken': 540,
#          'forbid': 540,
#          'drag': 539,
#          'colour': 539,
#          'divorce': 538,
#          'melt': 538,
#          'detach': 536,
#          'wave': 536,
#          'upset': 534,
#          'value': 533,
#          'entertain': 532,
#          'wrap': 532,
#          'shake': 531,
#          'unite': 531,
#          'swear': 530,
#          'Outstanding': 530,
#          'deposit': 529,
#          'acclaim': 526,
#          'cool': 526,
#          'reign': 526,
#          'align': 525,
#          'prevail': 523,
#          'Starting': 521,
#          'await': 520,
#          'motivate': 516,
#          'slip': 516,
#          ...})

# %%
most_common_verbs
# Out:
# ('be',
#  'have',
#  'make',
#  'include',
#  'use',
#  'do',
#  'become',
#  'take',
#  'write',
#  'say',
#  'begin',
#  'give',
#  'know',
#  'play',
#  'find',
#  'call',
#  'go',
#  'release',
#  'win',
#  'lead',
#  'receive',
#  'follow',
#  'leave',
#  'come',
#  'remain',
#  'continue',
#  'describe',
#  'move',
#  'work',
#  'hold',
#  'appear',
#  'return',
#  'see',
#  'build',
#  'produce',
#  'create',
#  'reach',
#  'provide',
#  'base',
#  'allow',
#  'name',
#  'serve',
#  'run',
#  'show',
#  'consider',
#  'feature',
#  'state',
#  'start',
#  'get',
#  'record')

# %%
counts = {verb: dict() for verb in most_common_verbs}
for i in range(len(dataset)):
    if dataset[i] in most_common_verbs:
        nouns = counts[dataset[i]]
        next_word = dataset[i+1]
        if next_word.isalpha() and tagged_dataset[i+1][1].startswith('N'):
            nouns[dataset[i+1]] = nouns.get(dataset[i+1], 0) + 1
for verb in counts:
    counts[verb] = dict(sorted(counts[verb].items(), key=lambda x: x[1], reverse=True)[:50])

# %%
for verb in counts:
    print(verb)
# Out:
# be
# have
# make
# include
# use
# do
# become
# take
# write
# say
# begin
# give
# know
# play
# find
# call
# go
# release
# win
# lead
# receive
# follow
# leave
# come
# remain
# continue
# describe
# move
# work
# hold
# appear
# return
# see
# build
# produce
# create
# reach
# provide
# base
# allow
# name
# serve
# run
# show
# consider
# feature
# state
# start
# get
# record

# %%
for verb in counts:
    print(verb, counts[verb])
# Out:
# be {'part': 3139, 'something': 518, 'evidence': 353, 'nothing': 351, 'member': 309, 'today': 264, 'briefly': 251, 'home': 249, 'time': 219, 'John': 196, 'kind': 151, 'friend': 127, 'president': 118, 'anything': 106, 'report': 102, 'concern': 99, 'people': 89, 'number': 88, 'William': 87, 'speculation': 85, 'plan': 84, 'fond': 80, 'US': 79, 'reminiscent': 77, 'chairman': 76, 'James': 71, 'proud': 70, 'prone': 67, 'Robert': 66, 'water': 65, 'example': 63, 'Hurricane': 63, 'woman': 60, 'unaware': 60, 'New': 59, 'Grade': 59, 'Michael': 59, 'sunk': 58, 'sort': 57, 'Australia': 57, 'Latin': 57, 'Captain': 56, 'President': 56, 'child': 56, 'men': 55, 'God': 54, 'hand': 54, 'St': 53, 'darker': 52, 'Richard': 52}
# %%
with open('data.json', 'w') as f:
    json.dump(counts, f)

# %%
def intersections(verb1, verb2):
    return set(counts[verb1].keys()) & set(counts[verb2].keys())

# %%
for verb1 in counts:
    for verb2 in counts:
        if verb1 != verb2:
            print(verb1, verb2, intersections(verb1, verb2))
# Out:
# be have {'something', 'briefly', 'nothing', 'time', 'child', 'plan', 'people', 'concern', 'anything'}
# be make {'part', 'plan', 'people', 'something', 'friend'}
# be include {'St', 'part', 'New', 'William', 'Robert', 'member', 'James', 'Captain', 'Richard', 'woman', 'John', 'Michael', 'Australia', 'child', 'President'}
# be use {'part', 'today', 'hand', 'water', 'time'}
# be do {'nothing', 'today', 'James', 'kind', 'God', 'something', 'anything'}
# be become {'president', 'home', 'New', 'part', 'member', 'US', 'President', 'chairman', 'something', 'friend'}
# be take {'home', 'time', 'part'}
# be write {'evidence', 'home', 'something', 'anything'}
# be say {'New', 'nothing', 'John', 'Michael', 'something', 'anything'}
# be begin {'plan'}
# be give {'evidence', 'woman', 'time', 'number', 'people'}
# be know {'example', 'nothing', 'today', 'God', 'people', 'something', 'anything'}
# be play {'home', 'time', 'part', 'something'}
# be find {'evidence', 'nothing', 'today', 'water', 'time', 'God', 'people', 'something', 'anything'}
# be call {'home', 'New', 'Robert', 'William', 'James', 'time', 'John'}
# be go {'home', 'concern', 'hand'}
# be release {'water'}
# be win {'home', 'time'}
# be lead {'member', 'men', 'time', 'Australia', 'people'}
# be receive {'water', 'report'}
# be follow {'part', 'report', 'US', 'John', 'Hurricane', 'concern'}
# be leave {'home', 'part', 'New', 'hand', 'Australia'}
# be come {'home', 'time', 'briefly'}
# be remain {'president', 'part', 'example', 'member', 'today', 'men', 'time', 'number', 'friend', 'unaware'}
# be continue {'today', 'New'}
# be describe {'St', 'William', 'men', 'James', 'John', 'God', 'something'}
# be move {'home', 'part', 'briefly', 'water', 'people'}
# be work {'part', 'briefly', 'today', 'men', 'woman', 'people'}
# be hold {'part', 'New', 'hand', 'number'}
# be appear {'today', 'darker', 'briefly'}
# be return {'home', 'John', 'briefly'}
# be see {'evidence', 'nothing', 'today', 'Michael', 'God', 'people', 'something', 'anything'}
# be build {'St', 'home', 'something'}
# be produce {'water', 'something', 'anything', 'child'}
# be create {'water', 'something', 'concern'}
# be reach {'St', 'New', 'number', 'US'}
# be provide {'evidence', 'water'}
# be base set()
# be allow {'part', 'member', 'James', 'woman', 'water', 'time', 'Michael', 'Australia', 'child', 'people'}
# be name {'evidence', 'president', 'New', 'William', 'Robert', 'James', 'Captain', 'Richard', 'John', 'Michael', 'chairman'}
# be serve {'St', 'New', 'member', 'briefly', 'US', 'time', 'God'}
# be run {'water', 'time', 'home', 'number'}
# be show {'evidence', 'people', 'concern'}
# be consider {'evidence', 'part', 'William', 'today', 'men', 'child', 'reminiscent', 'something'}
# be feature {'John', 'Michael'}
# be state set()
# be start {'time'}
# be get {'home', 'nothing', 'woman', 'water', 'time', 'kind', 'people', 'something', 'anything'}
# be record {'home', 'time', 'number'}
# have be {'something', 'briefly', 'nothing', 'time', 'child', 'plan', 'people', 'concern', 'anything'}
# have make {'room', 'fun', 'plan', 'people', 'something'}
# have include {'element', 'child'}
# have use {'time', 'element', 'power'}
# have do {'nothing', 'feature', 'everything', 'something', 'anything'}
# have become {'something'}
# have take {'control', 'time', 'issue', 'responsibility', 'office', 'influence', 'power'}
# have write {'something', 'anything'}
# have say {'everything', 'something', 'anything', 'nothing'}
# have begin {'plan'}
# have give {'control', 'time', 'responsibility', 'priority', 'people', 'access'}
# have know {'nothing', 'feature', 'everything', 'people', 'something', 'anything'}
# have play {'role', 'time', 'something'}
# have find {'similarity', 'nothing', 'element', 'wind', 'someone', 'problem', 'time', 'difficulty', 'none', 'success', 'influence', 'people', 'something', 'anything'}
# have call {'time'}
# have go {'concern'}
# have release {'feature'}
# have win {'control', 'time', 'none'}
# have lead {'time', 'role', 'people', 'element', 'power'}
# have receive set()
# have follow {'concern'}
# have leave {'office', 'room', 'everything'}
# have come {'time', 'briefly'}
# have remain {'family', 'time', 'element'}
# have continue {'success', 'influence', 'problem', 'role'}
# have describe {'someone', 'something', 'feeling'}
# have move {'people', 'element', 'briefly'}
# have work {'cost', 'experience', 'people', 'briefly'}
# have hold {'office', 'power'}
# have appear {'cancer', 'briefly'}
# have return {'control', 'briefly'}
# have see {'vision', 'similarity', 'nothing', 'element', 'someone', 'everything', 'people', 'something', 'anything'}
# have build {'something'}
# have produce {'wind', 'child', 'anything', 'something', 'power'}
# have create {'concern', 'problem', 'difficulty', 'something', 'doubt'}
# have reach {'lunch', 'wind', 'dimension'}
# have provide {'access', 'power'}
# have base {'element'}
# have allow {'room', 'connection', 'time', 'child', 'people', 'access'}
# have name set()
# have serve {'lunch', 'time', 'briefly'}
# have run {'time'}
# have show {'influence', 'people', 'similarity', 'concern'}
# have consider {'something', 'child'}
# have feature {'element'}
# have state {'office', 'control'}
# have start {'time'}
# have get {'control', 'access', 'nothing', 'wind', 'plenty', 'everything', 'someone', 'time', 'people', 'something', 'anything'}
# have record {'time', 'wind'}
# make be {'part', 'plan', 'people', 'something', 'friend'}
# make have {'room', 'fun', 'plan', 'people', 'something'}
# make include {'part', 'reference', 'music', 'appearance'}
# make use {'part', 'change', 'music'}
# make do {'music', 'thing', 'something', 'note'}
# make become {'part', 'law', 'something', 'friend'}
# make take {'matter', 'part', 'note'}
# make write {'law', 'history', 'reference', 'statement', 'music', 'something'}
# make say {'thing', 'something'}
# make begin {'repair', 'life', 'effort', 'preparation', 'plan'}
# make give {'life', 'money', 'way', 'speech', 'player', 'people'}
# make know {'film', 'use', 'reference', 'people', 'something'}
# make play {'part', 'music', 'something', 'game'}
# make find {'life', 'peace', 'love', 'way', 'people', 'thing', 'something'}
# make call set()
# make go set()
# make release {'film', 'history', 'music', 'game'}
# make win {'game'}
# make lead {'change', 'people', 'player'}
# make receive {'money'}
# make follow {'part', 'change', 'player'}
# make leave {'part', 'room', 'port'}
# make come {'war'}
# make remain {'part', 'game', 'friend', 'player'}
# make continue {'effort', 'use'}
# make describe {'something', 'life'}
# make move {'part', 'people', 'speech'}
# make work {'camp', 'part', 'people', 'life'}
# make hold {'part', 'port'}
# make appear set()
# make return {'appearance', 'game', 'player'}
# make see {'film', 'life', 'use', 'people', 'thing', 'something'}
# make build {'structure', 'something'}
# make produce {'film', 'music', 'something', 'game'}
# make create {'life', 'music', 'something', 'game'}
# make reach {'port'}
# make provide {'money', 'music', 'player'}
# make base {'film', 'game', 'camp', 'observation', 'music'}
# make allow {'part', 'use', 'room', 'player', 'people'}
# make name {'change', 'player'}
# make serve {'player'}
# make run {'game'}
# make show {'film', 'people', 'appearance'}
# make consider {'war', 'part', 'music', 'something'}
# make feature {'film', 'reference', 'music', 'appearance'}
# make state {'law'}
# make start {'appearance', 'game', 'life'}
# make get {'money', 'people', 'thing', 'something'}
# make record {'history', 'music', 'player', 'use'}
# include be {'St', 'part', 'New', 'William', 'Robert', 'member', 'James', 'Captain', 'Richard', 'woman', 'John', 'Michael', 'Australia', 'child', 'President'}
# include have {'element', 'child'}
# include make {'part', 'reference', 'music', 'appearance'}
# include use {'part', 'character', 'information', 'music', 'element', 'performance'}
# include do {'work', 'interview', 'James', 'song', 'music'}
# include become {'part', 'New', 'member', 'Lord', 'President'}
# include take {'part'}
# include write {'character', 'work', 'reference', 'song', 'music'}
# include say {'New', 'Tom', 'John', 'Thomas', 'Michael'}
# include begin {'work', 'construction'}
# include give {'interview', 'woman', 'area', 'land', 'information'}
# include know {'one', 'work', 'character', 'reference', 'actor', 'song'}
# include play {'part', 'Sir', 'Jack', 'area', 'song', 'music'}
# include find {'work', 'element', 'information'}
# include call {'New', 'William', 'Robert', 'Sir', 'Peter', 'James', 'John', 'Thomas', 'George', 'Henry'}
# include go set()
# include release {'music', 'information', 'song', 'A'}
# include win {'Best', 'performance'}
# include lead {'member', 'character', 'actor', 'Australia', 'element'}
# include receive {'information'}
# include follow {'Peter', 'part', 'John'}
# include leave {'part', 'New', 'Australia', 'France', 'Henry'}
# include come {'actor'}
# include remain {'part', 'member', 'work', 'area', 'land', 'song', 'element'}
# include continue {'work', 'New'}
# include describe {'St', 'William', 'James', 'John', 'Paul'}
# include move {'part', 'element'}
# include work {'woman', 'part', 'area'}
# include hold {'area', 'part', 'New', 'land'}
# include appear {'character'}
# include return {'character', 'Peter', 'John', 'Henry', 'appearance'}
# include see {'Jack', 'Peter', 'Michael', 'Mark', 'element'}
# include build {'St', 'work', 'character'}
# include produce {'work', 'music', 'song', 'child'}
# include create {'character', 'work', 'area', 'song', 'music', 'scene'}
# include reach {'St', 'New', 'land', 'France'}
# include provide {'music', 'information'}
# include base {'area', 'music', 'element', 'construction'}
# include allow {'part', 'member', 'James', 'woman', 'human', 'Michael', 'Australia', 'child', 'construction', 'Henry'}
# include name {'William', 'New', 'Robert', 'Jack', 'Peter', 'George', 'James', 'Captain', 'Richard', 'John', 'Michael', 'Thomas', 'Best', 'Henry'}
# include serve {'St', 'New', 'Henry', 'member'}
# include run set()
# include show {'character', 'Peter', 'scene', 'appearance', 'performance'}
# include consider {'part', 'William', 'work', 'land', 'child', 'music', 'Henry'}
# include feature {'character', 'work', 'Peter', 'interview', 'reference', 'scene', 'actor', 'John', 'Michael', 'song', 'David', 'Paul', 'music', 'element', 'appearance', 'performance'}
# include state set()
# include start {'work', 'construction', 'appearance'}
# include get {'work', 'information', 'woman'}
# include record {'music', 'song'}
# use be {'part', 'today', 'hand', 'water', 'time'}
# use have {'time', 'element', 'power'}
# use make {'part', 'change', 'music'}
# use include {'part', 'character', 'information', 'music', 'element', 'performance'}
# use do {'today', 'music', 'drug'}
# use become {'part'}
# use take {'part', 'time', 'power', 'drug'}
# use write {'character', 'material', 'music', 'word'}
# use say set()
# use begin {'development'}
# use give {'time', 'information', 'name'}
# use know {'today', 'material', 'name', 'character'}
# use play {'part', 'time', 'music', 'instrument'}
# use find {'today', 'water', 'time', 'information', 'item', 'element'}
# use call {'time'}
# use go {'hand'}
# use release {'water', 'information', 'hydrogen', 'music', 'material'}
# use win {'time', 'performance'}
# use lead {'character', 'change', 'time', 'element', 'power', 'force'}
# use receive {'water', 'information', 'word'}
# use follow {'part', 'change'}
# use leave {'part', 'hand'}
# use come {'time', 'force'}
# use remain {'part', 'today', 'time', 'fund', 'force', 'element', 'material'}
# use continue {'today', 'development'}
# use describe set()
# use move {'part', 'vehicle', 'air', 'water', 'element', 'force'}
# use work {'today', 'part', 'force'}
# use hold {'part', 'hand', 'power'}
# use appear {'today', 'character'}
# use return {'character'}
# use see {'today', 'footage', 'element'}
# use build {'stone', 'material', 'character'}
# use produce {'steam', 'oil', 'water', 'music', 'power'}
# use create {'water', 'music', 'character'}
# use reach set()
# use provide {'steam', 'air', 'water', 'information', 'fund', 'music', 'data', 'power', 'material'}
# use base {'method', 'computer', 'music', 'element', 'material'}
# use allow {'water', 'time', 'part', 'air'}
# use name {'Sea', 'change'}
# use serve {'time', 'weapon'}
# use run {'water', 'time'}
# use show {'footage', 'performance', 'character'}
# use consider {'today', 'part', 'music', 'name'}
# use feature {'character', 'footage', 'music', 'element', 'performance'}
# use state {'fund'}
# use start {'time', 'development', 'material'}
# use get {'water', 'time', 'information', 'word'}
# use record {'music', 'time', 'technique', 'material'}
# do be {'nothing', 'today', 'James', 'kind', 'God', 'something', 'anything'}
# do have {'nothing', 'feature', 'everything', 'something', 'anything'}
# do make {'music', 'thing', 'something', 'note'}
# do include {'work', 'interview', 'James', 'song', 'music'}
# do use {'today', 'music', 'drug'}
# do become {'something'}
# do take {'drug', 'credit', 'note'}
# do write {'work', 'credit', 'song', 'record', 'music', 'something', 'anything'}
# do say {'nothing', 'everything', 'thing', 'something', 'anything'}
# do begin {'work', 'research'}
# do give {'battle', 'interview', 'credit', 'voice'}
# do know {'feature', 'today', 'work', 'nothing', 'everything', 'anyone', 'song', 'record', 'God', 'something', 'anything'}
# do play {'music', 'something', 'song'}
# do find {'nothing', 'work', 'today', 'anyone', 'God', 'thing', 'something', 'anything'}
# do call {'James'}
# do go set()
# do release {'record', 'music', 'song', 'feature'}
# do win {'share', 'record'}
# do lead set()
# do receive {'credit'}
# do follow set()
# do leave {'everything'}
# do come {'record'}
# do remain {'today', 'state', 'work', 'song'}
# do continue {'today', 'work', 'research', 'practice'}
# do describe {'God', 'James', 'something'}
# do move set()
# do work {'today', 'practice'}
# do hold {'record'}
# do appear {'today'}
# do return set()
# do see {'nothing', 'today', 'everything', 'anyone', 'God', 'thing', 'something', 'anything'}
# do build {'work', 'something'}
# do produce {'work', 'song', 'record', 'music', 'something', 'anything'}
# do create {'work', 'music', 'something', 'song'}
# do reach set()
# do provide {'voice', 'music'}
# do base {'battle', 'music'}
# do allow {'anyone', 'state', 'James'}
# do name {'James'}
# do serve {'God', 'justice'}
# do run {'record'}
# do show {'business'}
# do consider {'today', 'state', 'work', 'music', 'something'}
# do feature {'work', 'interview', 'music', 'song'}
# do state {'record'}
# do start {'work'}
# do get {'justice', 'nothing', 'work', 'credit', 'everything', 'kind', 'thing', 'something', 'anything'}
# do record {'music', 'song'}
# become be {'president', 'home', 'New', 'part', 'member', 'US', 'President', 'chairman', 'something', 'friend'}
# become have {'something'}
# become make {'part', 'law', 'something', 'friend'}
# become include {'part', 'New', 'member', 'Lord', 'President'}
# become use {'part'}
# become do {'something'}
# become take {'home', 'prisoner', 'part'}
# become write {'home', 'law', 'something'}
# become say {'something', 'New', 'Cyrus'}
# become begin set()
# become give set()
# become know {'something', 'hurricane'}
# become play {'home', 'part', 'something'}
# become find {'something', 'Beyoncé'}
# become call {'home', 'New', 'King', 'Carey', 'Route'}
# become go {'head', 'home'}
# become release {'prisoner'}
# become win {'home', 'director'}
# become lead {'member'}
# become receive set()
# become follow {'Main', 'part', 'State', 'King', 'Route', 'US', 'NY'}
# become leave {'NY', 'New', 'home', 'part'}
# become come {'home'}
# become remain {'president', 'part', 'member', 'prisoner', 'friend'}
# become continue {'New'}
# become describe {'King', 'Madonna', 'Carey', 'something', 'Beyoncé'}
# become move {'home', 'part'}
# become work {'part'}
# become hold {'part', 'prisoner', 'New'}
# become appear set()
# become return {'home'}
# become see {'something'}
# become build {'home', 'something', 'Route'}
# become produce {'something', 'hurricane'}
# become create {'something', 'Route'}
# become reach {'New', 'hurricane', 'US'}
# become provide set()
# become base set()
# become allow {'part', 'member'}
# become name {'president', 'Tropical', 'New', 'captain', 'chairman'}
# become serve {'New', 'King', 'member', 'governor', 'Route', 'US'}
# become run {'home'}
# become show {'Madonna', 'Beyoncé', 'Gaga'}
# become consider {'part', 'something'}
# become feature {'Madonna', 'Cyrus', 'Carey', 'Rihanna', 'Beyoncé'}
# become state {'law', 'governor'}
# become start set()
# become get {'home', 'something'}
# become record {'home'}
# take be {'home', 'time', 'part'}
# take have {'control', 'time', 'issue', 'responsibility', 'office', 'influence', 'power'}
# take make {'matter', 'part', 'note'}
# take include {'part'}
# take use {'part', 'time', 'power', 'drug'}
# take do {'drug', 'credit', 'note'}
# take become {'home', 'prisoner', 'part'}
# take write {'order', 'home', 'credit', 'account'}
# take say set()
# take begin set()
# take give {'control', 'command', 'credit', 'effect', 'time', 'responsibility', 'notice', 'order'}
# take know set()
# take play {'home', 'time', 'part', 'match'}
# take find {'shelter', 'refuge', 'time', 'inspiration', 'influence'}
# take call {'home', 'time'}
# take go {'home', 'place'}
# take release {'prisoner'}
# take win {'home', 'control', 'time', 'side'}
# take lead {'time', 'power'}
# take receive {'order', 'command', 'credit', 'damage'}
# take follow {'part', 'order'}
# take leave {'office', 'home', 'part', 'turn'}
# take come {'home', 'time'}
# take remain {'part', 'prisoner', 'time'}
# take continue {'influence'}
# take describe set()
# take move {'home', 'picture', 'part'}
# take work {'part', 'class', 'order', 'place'}
# take hold {'part', 'command', 'position', 'class', 'office', 'prisoner', 'hostage', 'power'}
# take appear set()
# take return {'position', 'home', 'control', 'match'}
# take see {'picture', 'action'}
# take build {'home'}
# take produce {'power'}
# take create {'position', 'effect'}
# take reach {'position'}
# take provide {'cover', 'shelter', 'inspiration', 'power', 'care'}
# take base {'command'}
# take allow {'part', 'time'}
# take name set()
# take serve {'time'}
# take run {'home', 'time', 'order'}
# take show {'influence'}
# take consider {'part'}
# take feature set()
# take state {'office', 'control'}
# take start {'position', 'time', 'order', 'place'}
# take get {'home', 'control', 'credit', 'hold', 'revenge', 'time', 'inspiration'}
# take record {'home', 'time'}
# write be {'evidence', 'home', 'something', 'anything'}
# write have {'something', 'anything'}
# write make {'law', 'history', 'reference', 'statement', 'music', 'something'}
# write include {'character', 'work', 'reference', 'song', 'music'}
# write use {'character', 'material', 'music', 'word'}
# write do {'work', 'credit', 'song', 'record', 'music', 'something', 'anything'}
# write become {'home', 'law', 'something'}
# write take {'order', 'home', 'credit', 'account'}
# write say {'episode', 'something', 'anything'}
# write begin {'work', 'play'}
# write give {'evidence', 'credit', 'order'}
# write know {'form', 'character', 'work', 'book', 'reference', 'song', 'record', 'poem', 'something', 'anything', 'material'}
# write play {'home', 'career', 'style', 'song', 'music', 'something'}
# write find {'work', 'something', 'anything', 'evidence'}
# write call {'home', 'letter'}
# write go {'home', 'play'}
# write release {'history', 'song', 'record', 'music', 'material'}
# write win {'home', 'team', 'novel', 'record'}
# write lead {'team', 'story', 'character'}
# write receive {'word', 'credit', 'letter', 'message', 'order'}
# write follow {'episode', 'order'}
# write leave {'home'}
# write come {'home', 'campaign', 'record'}
# write remain {'work', 'team', 'song', 'material'}
# write continue {'work'}
# write describe {'something'}
# write move {'home'}
# write work {'team', 'order'}
# write hold {'record'}
# write appear {'character'}
# write return {'home', 'character'}
# write see {'evidence', 'something', 'anything'}
# write build {'home', 'character', 'work', 'something', 'material'}
# write produce {'work', 'book', 'partner', 'episode', 'song', 'record', 'music', 'something', 'anything'}
# write create {'character', 'work', 'song', 'music', 'something'}
# write reach set()
# write provide {'evidence', 'music', 'material'}
# write base {'story', 'episode', 'system', 'team', 'music', 'material'}
# write allow {'team'}
# write name {'evidence', 'team'}
# write serve set()
# write run {'home', 'play', 'order', 'record'}
# write show {'evidence', 'episode', 'character'}
# write consider {'work', 'music', 'something', 'evidence'}
# write feature {'story', 'lyric', 'work', 'character', 'reference', 'song', 'article', 'music'}
# write state {'law', 'team', 'record'}
# write start {'work', 'play', 'order', 'material'}
# write get {'home', 'word', 'work', 'credit', 'something', 'anything'}
# write record {'home', 'career', 'book', 'history', 'process', 'song', 'music', 'material'}
# say be {'New', 'nothing', 'John', 'Michael', 'something', 'anything'}
# say have {'everything', 'something', 'anything', 'nothing'}
# say make {'thing', 'something'}
# say include {'New', 'Tom', 'John', 'Thomas', 'Michael'}
# say use set()
# say do {'nothing', 'everything', 'thing', 'something', 'anything'}
# say become {'something', 'New', 'Cyrus'}
# say take set()
# say write {'episode', 'something', 'anything'}
# say begin set()
# say give {'year'}
# say know {'everything', 'something', 'anything', 'nothing'}
# say play {'something'}
# say find {'thing', 'something', 'anything', 'nothing'}
# say call {'New', 'Chris', 'John', 'Thomas', 'Jackson'}
# say go set()
# say release set()
# say win set()
# say lead set()
# say receive set()
# say follow {'Clark', 'year', 'Chris', 'episode', 'John'}
# say leave {'New', 'everything'}
# say come {'year', 'afterwards'}
# say remain {'year', 'territory'}
# say continue {'New'}
# say describe {'Smith', 'Johnson', 'John', 'Jackson', 'something'}
# say move set()
# say work set()
# say hold {'territory', 'New'}
# say appear {'year'}
# say return {'John'}
# say see {'nothing', 'everything', 'Michael', 'thing', 'something', 'anything'}
# say build {'something'}
# say produce {'episode', 'something', 'anything'}
# say create {'something'}
# say reach {'New'}
# say provide set()
# say base {'episode'}
# say allow {'Michael'}
# say name {'New', 'John', 'Thomas', 'Michael'}
# say serve {'New'}
# say run set()
# say show {'Jackson', 'episode'}
# say consider {'something'}
# say feature {'Cyrus', 'Michael', 'John', 'Spears', 'Jay'}
# say state set()
# say start set()
# say get {'nothing', 'everything', 'thing', 'something', 'anything'}
# say record set()
# begin be {'plan'}
# begin have {'plan'}
# begin make {'repair', 'life', 'effort', 'preparation', 'plan'}
# begin include {'work', 'construction'}
# begin use {'development'}
# begin do {'work', 'research'}
# begin become set()
# begin take set()
# begin write {'work', 'play'}
# begin say set()
# begin give {'life'}
# begin know {'work'}
# begin play {'college'}
# begin find {'work', 'life'}
# begin call {'Operation'}
# begin go {'play'}
# begin release {'May', 'January', 'July', 'August', 'February', 'November', 'September', 'June', 'December', 'October', 'April', 'March'}
# begin win {'promotion'}
# begin lead set()
# begin receive {'training'}
# begin follow {'Operation'}
# begin leave {'college', 'school'}
# begin come {'May', 'attack'}
# begin remain {'work'}
# begin continue {'service', 'publication', 'effort', 'work', 'negotiation', 'development', 'production', 'operation', 'study', 'training', 'research'}
# begin describe {'life'}
# begin move {'production'}
# begin work {'life'}
# begin hold {'service', 'September', 'negotiation', 'June', 'discussion', 'talk'}
# begin appear {'July'}
# begin return {'flight', 'April'}
# begin see {'service', 'life'}
# begin build {'work', 'c'}
# begin produce {'work'}
# begin create {'work', 'life'}
# begin reach {'sale'}
# begin provide {'service', 'training'}
# begin base {'service', 'operation', 'construction'}
# begin allow {'construction'}
# begin name {'Operation'}
# begin serve set()
# begin run {'service', 'play', 'attack', 'school'}
# begin show set()
# begin consider {'work'}
# begin feature {'work', 'production'}
# begin state {'school'}
# begin start {'service', 'flight', 'play', 'life', 'work', 'September', 'negotiation', 'development', 'December', 'production', 'construction', 'operation', 'January', 'school'}
# begin get {'work'}
# begin record {'sale'}
# give be {'evidence', 'woman', 'time', 'number', 'people'}
# give have {'control', 'time', 'responsibility', 'priority', 'people', 'access'}
# give make {'life', 'money', 'way', 'speech', 'player', 'people'}
# give include {'interview', 'woman', 'area', 'land', 'information'}
# give use {'time', 'information', 'name'}
# give do {'battle', 'interview', 'credit', 'voice'}
# give become set()
# give take {'control', 'command', 'credit', 'effect', 'time', 'responsibility', 'notice', 'order'}
# give write {'evidence', 'credit', 'order'}
# give say {'year'}
# give begin {'life'}
# give know {'people', 'name'}
# give play {'area', 'time'}
# give find {'evidence', 'life', 'support', 'time', 'way', 'information', 'people'}
# give call {'time'}
# give go set()
# give release {'point', 'information', 'day'}
# give win {'control', 'praise', 'support', 'point', 'time'}
# give lead {'Michigan', 'time', 'people', 'player'}
# give receive {'command', 'approval', 'praise', 'support', 'credit', 'money', 'instruction', 'permission', 'information', 'order'}
# give follow {'Michigan', 'year', 'order', 'player'}
# give leave set()
# give come {'year', 'time', 'day'}
# give remain {'year', 'area', 'time', 'land', 'player', 'number'}
# give continue {'support'}
# give describe {'life'}
# give move {'people', 'Arsenal', 'speech'}
# give work {'life', 'woman', 'area', 'people', 'order', 'day'}
# give hold {'area', 'command', 'land', 'number'}
# give appear {'year'}
# give return {'control', 'player'}
# give see {'evidence', 'people', 'life'}
# give build {'support'}
# give produce set()
# give create {'area', 'effect', 'life'}
# give reach {'land', 'number'}
# give provide {'evidence', 'detail', 'support', 'advice', 'money', 'information', 'player', 'voice', 'access'}
# give base {'battle', 'command', 'area'}
# give allow {'viewer', 'fan', 'woman', 'time', 'player', 'people', 'access'}
# give name {'evidence', 'player'}
# give serve {'time', 'player'}
# give run {'time', 'support', 'order', 'number'}
# give show {'evidence', 'people', 'support', 'viewer'}
# give consider {'evidence', 'land', 'name'}
# give feature {'interview'}
# give state {'control'}
# give start {'point', 'time', 'order', 'life'}
# give get {'control', 'support', 'credit', 'advice', 'money', 'point', 'woman', 'permission', 'time', 'information', 'people', 'access'}
# give record {'time', 'player', 'number'}
# know be {'example', 'nothing', 'today', 'God', 'people', 'something', 'anything'}
# know have {'nothing', 'feature', 'everything', 'people', 'something', 'anything'}
# know make {'film', 'use', 'reference', 'people', 'something'}
# know include {'one', 'work', 'character', 'reference', 'actor', 'song'}
# know use {'today', 'material', 'name', 'character'}
# know do {'feature', 'work', 'today', 'nothing', 'everything', 'anyone', 'song', 'record', 'God', 'something', 'anything'}
# know become {'something', 'hurricane'}
# know take set()
# know write {'form', 'character', 'work', 'book', 'reference', 'song', 'record', 'poem', 'something', 'anything', 'material'}
# know say {'everything', 'something', 'anything', 'nothing'}
# know begin {'work'}
# know give {'people', 'name'}
# know play {'something', 'song'}
# know find {'nothing', 'work', 'today', 'anyone', 'God', 'people', 'something', 'anything'}
# know call set()
# know go set()
# know release {'film', 'site', 'feature', 'song', 'record', 'material'}
# know win {'record'}
# know lead {'group', 'composer', 'character', 'figure', 'artist', 'actor', 'writer', 'people'}
# know receive set()
# know follow set()
# know leave {'everything'}
# know come {'actor', 'record'}
# know remain {'group', 'example', 'today', 'work', 'specie', 'song', 'piece', 'population', 'material'}
# know continue {'today', 'work', 'use'}
# know describe {'God', 'specie', 'something'}
# know move {'group', 'people', 'piece'}
# know work {'group', 'site', 'today', 'people', 'population'}
# know hold {'record'}
# know appear {'today', 'character'}
# know return {'character'}
# know see {'film', 'use', 'today', 'figure', 'nothing', 'everything', 'anyone', 'God', 'people', 'something', 'anything'}
# know build {'work', 'material', 'something', 'character'}
# know produce {'film', 'work', 'book', 'hurricane', 'song', 'record', 'something', 'anything'}
# know create {'work', 'something', 'song', 'character'}
# know reach {'hurricane'}
# know provide {'material'}
# know base {'film', 'group', 'material'}
# know allow {'anyone', 'people', 'use'}
# know name set()
# know serve {'God'}
# know run {'line', 'record'}
# know show {'film', 'people', 'character'}
# know consider {'today', 'work', 'planet', 'something', 'name'}
# know feature {'film', 'character', 'work', 'reference', 'artist', 'actor', 'song'}
# know state {'line', 'record'}
# know start {'work', 'line', 'material'}
# know get {'nothing', 'work', 'everything', 'people', 'something', 'anything'}
# know record {'use', 'book', 'artist', 'song', 'material'}
# play be {'home', 'time', 'part', 'something'}
# play have {'role', 'time', 'something'}
# play make {'part', 'music', 'something', 'game'}
# play include {'part', 'Jack', 'Sir', 'area', 'song', 'music'}
# play use {'part', 'time', 'music', 'instrument'}
# play do {'music', 'something', 'song'}
# play become {'home', 'part', 'something'}
# play take {'home', 'time', 'part', 'match'}
# play write {'home', 'career', 'style', 'song', 'music', 'something'}
# play say {'something'}
# play begin {'college'}
# play give {'area', 'time'}
# play know {'something', 'song'}
# play find {'time', 'something'}
# play call {'home', 'Sir', 'card', 'time', 'center'}
# play go {'home'}
# play release {'music', 'song', 'game'}
# play win {'goal', 'home', 'game', 'time', 'field'}
# play lead {'guitar', 'time', 'role'}
# play receive set()
# play follow {'part'}
# play leave {'home', 'field', 'college', 'part'}
# play come {'home', 'time'}
# play remain {'part', 'game', 'area', 'time', 'song'}
# play continue {'role'}
# play describe {'something'}
# play move {'home', 'part'}
# play work {'area', 'part'}
# play hold {'area', 'part'}
# play appear set()
# play return {'home', 'game', 'match'}
# play see {'something', 'Jack'}
# play build {'home', 'something'}
# play produce {'game', 'show', 'song', 'music', 'something'}
# play create {'game', 'area', 'song', 'music', 'something', 'video'}
# play reach set()
# play provide {'music'}
# play base {'area', 'club', 'music', 'game'}
# play allow {'part', 'time'}
# play name {'American', 'Jack'}
# play serve {'time'}
# play run {'home', 'time', 'game'}
# play show {'center', 'host'}
# play consider {'part', 'Bond', 'music', 'something'}
# play feature {'American', 'music', 'song'}
# play state set()
# play start {'game', 'time', 'shortstop', 'center', 'quarterback'}
# play get {'home', 'time', 'something'}
# play record {'home', 'contract', 'career', 'time', 'song', 'music'}
# find be {'evidence', 'nothing', 'today', 'water', 'time', 'God', 'people', 'something', 'anything'}
# find have {'something', 'similarity', 'nothing', 'wind', 'someone', 'problem', 'time', 'difficulty', 'none', 'success', 'influence', 'people', 'element', 'anything'}
# find make {'life', 'peace', 'love', 'way', 'people', 'thing', 'something'}
# find include {'work', 'element', 'information'}
# find use {'today', 'water', 'time', 'information', 'item', 'element'}
# find do {'nothing', 'work', 'today', 'anyone', 'God', 'thing', 'something', 'anything'}
# find become {'something', 'Beyoncé'}
# find take {'shelter', 'refuge', 'time', 'inspiration', 'influence'}
# find write {'work', 'something', 'anything', 'evidence'}
# find say {'thing', 'something', 'anything', 'nothing'}
# find begin {'work', 'life'}
# find give {'evidence', 'life', 'support', 'time', 'way', 'information', 'people'}
# find know {'nothing', 'today', 'work', 'anyone', 'God', 'people', 'something', 'anything'}
# find play {'time', 'something'}
# find call {'time'}
# find go set()
# find release {'water', 'information'}
# find win {'support', 'time', 'none'}
# find lead {'people', 'element', 'time'}
# find receive {'water', 'help', 'support', 'information'}
# find follow set()
# find leave set()
# find come {'time'}
# find remain {'today', 'work', 'time', 'element'}
# find continue {'today', 'work', 'support', 'problem', 'success', 'influence'}
# find describe {'life', 'someone', 'God', 'something', 'Beyoncé'}
# find move {'food', 'object', 'water', 'people', 'element'}
# find work {'today', 'people', 'life'}
# find hold {'job'}
# find appear {'today'}
# find return set()
# find see {'evidence', 'something', 'similarity', 'life', 'nothing', 'today', 'someone', 'anyone', 'God', 'people', 'thing', 'element', 'anything'}
# find build {'work', 'space', 'support', 'something'}
# find produce {'work', 'wind', 'water', 'something', 'anything'}
# find create {'space', 'life', 'work', 'problem', 'water', 'difficulty', 'job', 'something'}
# find reach {'wind'}
# find provide {'evidence', 'space', 'food', 'support', 'shelter', 'water', 'employment', 'information', 'inspiration'}
# find base {'element'}
# find allow {'time', 'water', 'people', 'anyone'}
# find name {'evidence'}
# find serve {'God', 'time', 'food'}
# find run {'water', 'support', 'time'}
# find show {'evidence', 'similarity', 'support', 'influence', 'people', 'Beyoncé'}
# find consider {'today', 'work', 'something', 'evidence'}
# find feature {'work', 'element', 'Beyoncé'}
# find state set()
# find start {'work', 'time', 'life', 'job'}
# find get {'food', 'nothing', 'work', 'support', 'someone', 'wind', 'water', 'time', 'information', 'job', 'inspiration', 'help', 'people', 'thing', 'something', 'anything'}
# find record {'mention', 'time', 'wind'}
# call be {'home', 'New', 'Robert', 'William', 'James', 'time', 'John'}
# call have {'time'}
# call make set()
# call include {'New', 'William', 'Robert', 'Sir', 'Peter', 'James', 'John', 'Thomas', 'George', 'Henry'}
# call use {'time'}
# call do {'James'}
# call become {'home', 'New', 'King', 'Carey', 'Route'}
# call take {'home', 'time'}
# call write {'home', 'letter'}
# call say {'New', 'Chris', 'John', 'Thomas', 'Jackson'}
# call begin {'Operation'}
# call give {'time'}
# call know set()
# call play {'home', 'Sir', 'card', 'time', 'center'}
# call find {'time'}
# call go {'home'}
# call release {'Final'}
# call win {'time', 'home', 'La', 'Super'}
# call lead {'time'}
# call receive {'letter', 'vote', 'attention'}
# call follow {'King', 'West', 'Peter', 'Chris', 'Route', 'Operation', 'South', 'John'}
# call leave {'home', 'South', 'New', 'Henry'}
# call come {'home', 'time'}
# call remain {'time'}
# call continue {'New'}
# call describe {'William', 'King', 'Carey', 'James', 'John', 'Jackson'}
# call move {'home'}
# call work set()
# call hold {'New'}
# call appear set()
# call return {'Peter', 'home', 'John', 'Henry'}
# call see {'Peter', 'White', 'Angelou'}
# call build {'home', 'Fort', 'Route'}
# call produce set()
# call create {'Route'}
# call reach {'Fort', 'South', 'New'}
# call provide set()
# call base set()
# call allow {'Black', 'time', 'James', 'Henry'}
# call name {'William', 'New', 'Robert', 'Peter', 'Sam', 'Big', 'James', 'Operation', 'John', 'Thomas', 'George', 'Henry'}
# call serve {'New', 'King', 'girl', 'East', 'Route', 'Old', 'South', 'time', 'Henry'}
# call run {'home', 'time'}
# call show {'center', 'sign', 'Jackson', 'Peter'}
# call consider {'William', 'Henry', 'Angelou'}
# call feature {'Carey', 'John', 'Peter'}
# call state set()
# call start {'center', 'time'}
# call get {'home', 'Sam', 'time', 'attention'}
# call record {'home', 'time'}
# go be {'home', 'concern', 'hand'}
# go have {'concern'}
# go make set()
# go include set()
# go use {'hand'}
# go do set()
# go become {'head', 'home'}
# go take {'home', 'place'}
# go write {'home', 'play'}
# go say set()
# go begin {'play'}
# go give set()
# go know set()
# go play {'home'}
# go find set()
# go call {'home'}
# go release {'online'}
# go win {'gold', 'home'}
# go lead {'ship'}
# go receive set()
# go follow {'concern'}
# go leave {'home', 'homeless', 'hand'}
# go come {'online', 'home', 'onstage', 'towards', 'backstage', 'downstairs', 'round', 'top'}
# go remain {'ship'}
# go continue {'east', 'towards'}
# go describe set()
# go move {'home', 'towards', 'backwards', 'east', 'ship'}
# go work {'place', 'towards'}
# go hold {'scoreless', 'hand', 'penalty'}
# go appear {'online', 'dark', 'onstage', 'insane', 'east'}
# go return {'east', 'home', 'penalty'}
# go see set()
# go build {'home', 'ship'}
# go produce set()
# go create {'concern'}
# go reach set()
# go provide set()
# go base set()
# go allow set()
# go name set()
# go serve set()
# go run {'east', 'home', 'play', 'towards'}
# go show {'concern'}
# go consider set()
# go feature set()
# go state set()
# go start {'play', 'penalty', 'place'}
# go get {'home'}
# go record {'home'}
# release be {'water'}
# release have {'feature'}
# release make {'film', 'history', 'music', 'game'}
# release include {'music', 'information', 'song', 'A'}
# release use {'water', 'information', 'hydrogen', 'music', 'material'}
# release do {'record', 'music', 'song', 'feature'}
# release become {'prisoner'}
# release take {'prisoner'}
# release write {'history', 'song', 'record', 'music', 'material'}
# release say set()
# release begin {'May', 'January', 'July', 'August', 'February', 'November', 'September', 'June', 'December', 'October', 'April', 'March'}
# release give {'point', 'information', 'day'}
# release know {'film', 'site', 'feature', 'song', 'record', 'material'}
# release play {'music', 'song', 'game'}
# release find {'water', 'information'}
# release call {'Final'}
# release go {'online'}
# release win {'point', 'title', 'game', 'record'}
# release lead {'single', 'track'}
# release receive {'water', 'information'}
# release follow {'week', 'album'}
# release leave set()
# release come {'online', 'record', 'week', 'May', 'day'}
# release remain {'date', 'track', 'game', 'song', 'prisoner', 'material'}
# release continue set()
# release describe set()
# release move {'water'}
# release work {'site', 'party', 'title', 'schedule', 'week', 'day'}
# release hold {'September', 'record', 'prisoner', 'June'}
# release appear {'online', 'July'}
# release return {'April', 'game'}
# release see {'film'}
# release build {'material'}
# release produce {'film', 'game', 'water', 'album', 'song', 'record', 'version', 'music', 'track'}
# release create {'music', 'water', 'song', 'game'}
# release reach set()
# release provide {'water', 'music', 'information', 'material'}
# release base {'film', 'game', 'strategy', 'version', 'music', 'material'}
# release allow {'water'}
# release name set()
# release serve set()
# release run {'water', 'track', 'game', 'record'}
# release show {'film'}
# release consider {'music'}
# release feature {'film', 'music', 'song', 'track'}
# release state {'title', 'party', 'record'}
# release start {'game', 'September', 'point', 'December', 'date', 'January', 'material'}
# release get {'point', 'water', 'information'}
# release record {'material', 'history', 'album', 'song', 'version', 'music', 'track'}
# win be {'home', 'time'}
# win have {'control', 'time', 'none'}
# win make {'game'}
# win include {'Best', 'performance'}
# win use {'time', 'performance'}
# win do {'share', 'record'}
# win become {'home', 'director'}
# win take {'home', 'control', 'time', 'side'}
# win write {'home', 'team', 'novel', 'record'}
# win say set()
# win begin {'promotion'}
# win give {'control', 'praise', 'support', 'point', 'time'}
# win know {'record'}
# win play {'goal', 'home', 'game', 'time', 'field'}
# win find {'support', 'time', 'none'}
# win call {'time', 'home', 'La', 'Super'}
# win go {'gold', 'home'}
# win release {'point', 'title', 'game', 'record'}
# win lead {'team', 'time'}
# win receive {'award', 'praise', 'support'}
# win follow {'season'}
# win leave {'home', 'field'}
# win come {'season', 'time', 'home', 'record'}
# win remain {'team', 'time', 'game'}
# win continue {'support'}
# win describe set()
# win move {'home'}
# win work {'title', 'team', 'horse'}
# win hold {'election', 'record'}
# win appear set()
# win return {'home', 'control', 'game'}
# win see set()
# win build {'home', 'support'}
# win produce {'horse', 'game', 'record'}
# win create {'design', 'game'}
# win reach set()
# win provide {'support'}
# win base {'design', 'percentage', 'team', 'game'}
# win allow {'team', 'time'}
# win name {'Best', 'team'}
# win serve {'time'}
# win run {'home', 'total', 'game', 'support', 'time', 'record'}
# win show {'support', 'horse', 'performance'}
# win consider {'design', 'bid'}
# win feature {'performance'}
# win state {'control', 'election', 'title', 'record', 'team', 'championship'}
# win start {'Game', 'game', 'point', 'stage', 'time', 'pitcher'}
# win get {'home', 'control', 'support', 'point', 'time', 'shot'}
# win record {'home', 'time'}
# lead be {'member', 'men', 'time', 'Australia', 'people'}
# lead have {'time', 'role', 'people', 'element', 'power'}
# lead make {'change', 'people', 'player'}
# lead include {'member', 'character', 'actor', 'Australia', 'element'}
# lead use {'character', 'change', 'time', 'element', 'power', 'force'}
# lead do set()
# lead become {'member'}
# lead take {'time', 'power'}
# lead write {'team', 'story', 'character'}
# lead say set()
# lead begin set()
# lead give {'Michigan', 'time', 'people', 'player'}
# lead know {'group', 'composer', 'character', 'figure', 'artist', 'actor', 'writer', 'people'}
# lead play {'guitar', 'time', 'role'}
# lead find {'people', 'element', 'time'}
# lead call {'time'}
# lead go {'ship'}
# lead release {'single', 'track'}
# lead win {'team', 'time'}
# lead receive set()
# lead follow {'Michigan', 'change', 'player'}
# lead leave {'England', 'Australia'}
# lead come {'actor', 'time', 'force'}
# lead remain {'group', 'track', 'member', 'men', 'troop', 'time', 'player', 'ship', 'team', 'element', 'force'}
# lead continue {'role'}
# lead describe {'men'}
# lead move {'group', 'troop', 'ship', 'people', 'element', 'force'}
# lead work {'group', 'man', 'men', 'team', 'people', 'force'}
# lead hold {'company', 'power'}
# lead appear {'character'}
# lead return {'troop', 'man', 'player', 'character'}
# lead see {'figure', 'people', 'element'}
# lead build {'ship', 'man', 'character'}
# lead produce {'power', 'track'}
# lead create {'character'}
# lead reach {'No', 'England'}
# lead provide {'vocal', 'player', 'power'}
# lead base {'group', 'company', 'story', 'team', 'element'}
# lead allow {'company', 'member', 'scientist', 'time', 'player', 'Australia', 'team', 'people'}
# lead name {'change', 'man', 'team', 'player'}
# lead serve {'member', 'time', 'player'}
# lead run {'time', 'track'}
# lead show {'producer', 'people', 'character'}
# lead consider {'men', 'England'}
# lead feature {'story', 'character', 'artist', 'actor', 'vocal', 'element', 'track'}
# lead state {'team'}
# lead start {'time'}
# lead get {'people', 'time'}
# lead record {'artist', 'producer', 'time', 'player', 'vocal', 'company', 'track'}
# receive be {'water', 'report'}
# receive have set()
# receive make {'money'}
# receive include {'information'}
# receive use {'water', 'information', 'word'}
# receive do {'credit'}
# receive become set()
# receive take {'order', 'command', 'credit', 'damage'}
# receive write {'word', 'credit', 'letter', 'message', 'order'}
# receive say set()
# receive begin {'training'}
# receive give {'command', 'approval', 'praise', 'support', 'credit', 'money', 'instruction', 'permission', 'information', 'order'}
# receive know set()
# receive play set()
# receive find {'water', 'help', 'support', 'information'}
# receive call {'letter', 'vote', 'attention'}
# receive go set()
# receive release {'water', 'information'}
# receive win {'award', 'praise', 'support'}
# receive lead set()
# receive follow {'report', 'complaint', 'order'}
# receive leave set()
# receive come {'news'}
# receive remain set()
# receive continue {'support', 'training'}
# receive describe set()
# receive move {'water'}
# receive work {'order'}
# receive hold {'command', 'government'}
# receive appear set()
# receive return {'yard', 'touchdown'}
# receive see set()
# receive build {'support'}
# receive produce {'water'}
# receive create {'water'}
# receive reach set()
# receive provide {'aid', 'reinforcement', 'assistance', 'support', 'money', 'water', 'information', 'funding', 'training'}
# receive base {'radio', 'command'}
# receive allow {'water'}
# receive name {'recognition'}
# receive serve set()
# receive run {'water', 'radio', 'support', 'order'}
# receive show {'support'}
# receive consider set()
# receive feature set()
# receive state {'funding', 'government'}
# receive start {'order'}
# receive get {'word', 'support', 'credit', 'attention', 'money', 'water', 'permission', 'information', 'help'}
# receive record set()
# follow be {'part', 'report', 'US', 'John', 'Hurricane', 'concern'}
# follow have {'concern'}
# follow make {'part', 'change', 'player'}
# follow include {'Peter', 'part', 'John'}
# follow use {'part', 'change'}
# follow do set()
# follow become {'Main', 'part', 'State', 'King', 'Route', 'US', 'NY'}
# follow take {'part', 'order'}
# follow write {'episode', 'order'}
# follow say {'Chris', 'Clark', 'year', 'episode', 'John'}
# follow begin {'Operation'}
# follow give {'Michigan', 'year', 'order', 'player'}
# follow know set()
# follow play {'part'}
# follow find set()
# follow call {'King', 'West', 'Peter', 'Chris', 'Route', 'Operation', 'South', 'John'}
# follow go {'concern'}
# follow release {'week', 'album'}
# follow win {'season'}
# follow lead {'Michigan', 'change', 'player'}
# follow receive {'report', 'complaint', 'order'}
# follow leave {'NY', 'South', 'part'}
# follow come {'decade', 'year', 'month', 'season', 'week'}
# follow remain {'year', 'part', 'player'}
# follow continue set()
# follow describe {'John', 'King'}
# follow move {'part'}
# follow work {'week', 'part', 'order'}
# follow hold {'part'}
# follow appear {'year'}
# follow return {'Peter', 'John', 'player'}
# follow see {'Peter', 'table'}
# follow build {'Route'}
# follow produce {'episode', 'album'}
# follow create {'concern', 'Route'}
# follow reach {'South', 'Washington', 'Lake', 'US'}
# follow provide {'player'}
# follow base {'episode'}
# follow allow {'part', 'player'}
# follow name {'Peter', 'Operation', 'change', 'John', 'player'}
# follow serve {'King', 'Route', 'US', 'South', 'player'}
# follow run {'order'}
# follow show {'Peter', 'episode', 'concern'}
# follow consider {'part'}
# follow feature {'Peter', 'John'}
# follow state set()
# follow start {'World', 'order'}
# follow get set()
# follow record {'album', 'player'}
# leave be {'home', 'part', 'New', 'hand', 'Australia'}
# leave have {'office', 'room', 'everything'}
# leave make {'part', 'room', 'port'}
# leave include {'part', 'New', 'Australia', 'France', 'Henry'}
# leave use {'part', 'hand'}
# leave do {'everything'}
# leave become {'NY', 'New', 'home', 'part'}
# leave take {'office', 'home', 'part', 'turn'}
# leave write {'home'}
# leave say {'New', 'everything'}
# leave begin {'college', 'school'}
# leave give set()
# leave know {'everything'}
# leave play {'home', 'field', 'college', 'part'}
# leave find set()
# leave call {'home', 'South', 'New', 'Henry'}
# leave go {'home', 'homeless', 'hand'}
# leave release set()
# leave win {'home', 'field'}
# leave lead {'England', 'Australia'}
# leave receive set()
# leave follow {'NY', 'South', 'part'}
# leave come {'home'}
# leave remain {'part'}
# leave continue {'New'}
# leave describe set()
# leave move {'home', 'part'}
# leave work {'part'}
# leave hold {'part', 'New', 'hand', 'office', 'port'}
# leave appear set()
# leave return {'home', 'Henry'}
# leave see {'everything'}
# leave build {'home'}
# leave produce set()
# leave create {'hundred'}
# leave reach {'Britain', 'New', 'England', 'San', 'Earth', 'South', 'London', 'France', 'port', 'Boston'}
# leave provide set()
# leave base set()
# leave allow {'part', 'room', 'Henry', 'Australia'}
# leave name {'New', 'Henry'}
# leave serve {'New', 'South', 'London', 'town', 'Henry'}
# leave run {'home', 'school'}
# leave show set()
# leave consider {'Britain', 'part', 'England', 'Henry'}
# leave feature set()
# leave state {'office', 'politics', 'school'}
# leave start {'school'}
# leave get {'home', 'everything'}
# leave record {'home'}
# come be {'home', 'time', 'briefly'}
# come have {'time', 'briefly'}
# come make {'war'}
# come include {'actor'}
# come use {'time', 'force'}
# come do {'record'}
# come become {'home'}
# come take {'home', 'time'}
# come write {'home', 'campaign', 'record'}
# come say {'year', 'afterwards'}
# come begin {'May', 'attack'}
# come give {'year', 'time', 'day'}
# come know {'actor', 'record'}
# come play {'home', 'time'}
# come find {'time'}
# come call {'home', 'time'}
# come go {'online', 'home', 'onstage', 'towards', 'backstage', 'downstairs', 'round', 'top'}
# come release {'online', 'record', 'week', 'May', 'day'}
# come win {'season', 'time', 'home', 'record'}
# come lead {'actor', 'time', 'force'}
# come receive {'news'}
# come follow {'decade', 'year', 'month', 'season', 'week'}
# come leave {'home'}
# come remain {'year', 'time', 'force'}
# come continue {'towards'}
# come describe set()
# come move {'home', 'forward', 'towards', 'briefly', 'force'}
# ...
# run release {'water', 'track', 'game', 'record'}
# run win {'home', 'total', 'game', 'support', 'time', 'record'}
# run lead {'time', 'track'}
# run receive {'water', 'radio', 'support', 'order'}
# run follow {'order'}
# run leave {'home', 'school'}
# run come {'home', 'towards', 'time', 'attack', 'record'}
# run remain {'number', 'time', 'game', 'track'}
# run continue {'service', 'southeast', 'towards', 'support', 'series', 'east', 'west', 'north', 'south'}
# run describe {'event'}
# run move {'home', 'southeast', 'towards', 'east', 'water', 'north', 'west', 'south', 'train'}
# run work {'order', 'towards'}
# run hold {'service', 'event', 'number', 'record'}
# run appear {'east'}
# run return {'home', 'loss', 'game', 'series', 'east', 'north', 'south', 'average'}
# run see {'service'}
# run build {'south', 'home', 'north', 'support'}
# run produce {'game', 'television', 'series', 'water', 'record', 'track'}
# run create {'water', 'game'}
# run reach {'speed', 'number'}
# run provide {'service', 'water', 'support'}
# run base {'service', 'newspaper', 'radio', 'game'}
# run allow {'water', 'time', 'train'}
# run name {'right'}
# run serve {'time', 'train'}
# run show {'support'}
# run consider set()
# run feature {'track'}
# run state {'line', 'school', 'record'}
# run start {'service', 'play', 'game', 'time', 'line', 'order', 'school'}
# run get {'water', 'support', 'home', 'time'}
# run record {'home', 'number', 'time', 'victory', 'track'}
# show be {'evidence', 'people', 'concern'}
# show have {'influence', 'people', 'similarity', 'concern'}
# show make {'film', 'people', 'appearance'}
# show include {'character', 'Peter', 'scene', 'appearance', 'performance'}
# show use {'footage', 'performance', 'character'}
# show do {'business'}
# show become {'Madonna', 'Beyoncé', 'Gaga'}
# show take {'influence'}
# show write {'evidence', 'episode', 'character'}
# show say {'Jackson', 'episode'}
# show begin set()
# show give {'evidence', 'people', 'support', 'viewer'}
# show know {'film', 'people', 'character'}
# show play {'center', 'host'}
# show find {'evidence', 'similarity', 'support', 'influence', 'people', 'Beyoncé'}
# show call {'center', 'sign', 'Jackson', 'Peter'}
# show go {'concern'}
# show release {'film'}
# show win {'support', 'horse', 'performance'}
# show lead {'producer', 'people', 'character'}
# show receive {'support'}
# show follow {'Peter', 'episode', 'concern'}
# show leave set()
# show come {'runner'}
# show remain set()
# show continue {'interest', 'influence', 'support'}
# show describe {'Bart', 'Madonna', 'Harrison', 'Jackson', 'Beyoncé'}
# show move {'people', 'image'}
# show work {'people', 'horse'}
# show hold set()
# show appear {'character'}
# show return {'Peter', 'appearance', 'character'}
# show see {'Bart', 'film', 'evidence', 'image', 'similarity', 'Peter', 'Homer', 'footage', 'everyone', 'people'}
# show build {'support', 'character'}
# show produce {'film', 'episode', 'image', 'horse'}
# show create {'interest', 'image', 'concern', 'character', 'scene'}
# show reach set()
# show provide {'evidence', 'support'}
# show base {'film', 'episode'}
# show allow {'everyone', 'people', 'viewer'}
# show name {'Peter', 'evidence'}
# show serve set()
# show run {'support'}
# show consider {'evidence'}
# show feature {'clip', 'film', 'Madonna', 'image', 'character', 'Peter', 'Harrison', 'footage', 'appearance', 'scene', 'Beyoncé', 'performance'}
# show state set()
# show start {'center', 'appearance'}
# show get {'support', 'everyone', 'people', 'Homer'}
# show record {'producer'}
# consider be {'evidence', 'part', 'William', 'today', 'men', 'child', 'reminiscent', 'something'}
# consider have {'something', 'child'}
# consider make {'war', 'part', 'music', 'something'}
# consider include {'part', 'William', 'work', 'land', 'child', 'music', 'Henry'}
# consider use {'today', 'part', 'music', 'name'}
# consider do {'work', 'state', 'today', 'music', 'something'}
# consider become {'part', 'something'}
# consider take {'part'}
# consider write {'work', 'music', 'something', 'evidence'}
# consider say {'something'}
# consider begin {'work'}
# consider give {'evidence', 'land', 'name'}
# consider know {'today', 'work', 'planet', 'something', 'name'}
# consider play {'part', 'Bond', 'music', 'something'}
# consider find {'work', 'today', 'something', 'evidence'}
# consider call {'William', 'Henry', 'Angelou'}
# consider go set()
# consider release {'music'}
# consider win {'design', 'bid'}
# consider lead {'men', 'England'}
# consider receive set()
# consider follow {'part'}
# consider leave {'Britain', 'part', 'England', 'Henry'}
# consider come {'war'}
# consider remain {'part', 'today', 'state', 'work', 'men', 'land'}
# consider continue {'today', 'work'}
# consider describe {'men', 'William', 'something'}
# consider move {'part'}
# consider work {'today', 'part', 'men'}
# consider hold {'part', 'land', 'post'}
# consider appear {'today'}
# consider return {'Henry'}
# consider see {'today', 'something', 'evidence', 'Angelou'}
# consider build {'work', 'something'}
# consider produce {'work', 'music', 'something', 'child'}
# consider create {'work', 'design', 'post', 'music', 'legislation', 'something'}
# consider reach {'Britain', 'England', 'land'}
# consider provide {'evidence', 'music'}
# consider base {'design', 'music'}
# consider allow {'state', 'part', 'Henry', 'child'}
# consider name {'evidence', 'William', 'Henry'}
# consider serve {'Henry'}
# consider run set()
# consider show {'evidence'}
# consider feature {'work', 'collaboration', 'music'}
# consider state {'religion'}
# consider start {'work'}
# consider get {'work', 'something', 'idea'}
# consider record {'music'}
# feature be {'John', 'Michael'}
# feature have {'element'}
# feature make {'film', 'reference', 'music', 'appearance'}
# feature include {'character', 'work', 'Peter', 'interview', 'reference', 'scene', 'actor', 'John', 'Michael', 'David', 'song', 'Paul', 'music', 'element', 'appearance', 'performance'}
# feature use {'character', 'footage', 'music', 'element', 'performance'}
# feature do {'work', 'interview', 'music', 'song'}
# feature become {'Madonna', 'Cyrus', 'Carey', 'Rihanna', 'Beyoncé'}
# feature take set()
# feature write {'story', 'character', 'work', 'lyric', 'reference', 'song', 'article', 'music'}
# feature say {'Cyrus', 'Michael', 'John', 'Spears', 'Jay'}
# feature begin {'work', 'production'}
# feature give {'interview'}
# feature know {'film', 'character', 'work', 'reference', 'artist', 'actor', 'song'}
# feature play {'American', 'music', 'song'}
# feature find {'work', 'element', 'Beyoncé'}
# feature call {'Carey', 'John', 'Peter'}
# feature go set()
# feature release {'film', 'music', 'song', 'track'}
# feature win {'performance'}
# feature lead {'story', 'character', 'artist', 'actor', 'vocal', 'element', 'track'}
# feature receive set()
# feature follow {'Peter', 'John'}
# feature leave set()
# feature come {'actor'}
# feature remain {'work', 'element', 'song', 'track'}
# feature continue {'work', 'production'}
# feature describe {'Mulder', 'Madonna', 'Carey', 'Harrison', 'John', 'Paul', 'Beyoncé'}
# feature move {'image', 'element', 'production'}
# feature work set()
# feature hold set()
# feature appear {'character'}
# feature return {'Peter', 'John', 'appearance', 'character'}
# feature see {'Mulder', 'film', 'image', 'Peter', 'Michael', 'footage', 'element'}
# feature build {'work', 'character'}
# feature produce {'film', 'image', 'work', 'song', 'music', 'track'}
# feature create {'image', 'character', 'work', 'art', 'song', 'music', 'scene'}
# feature reach {'length'}
# feature provide {'vocal', 'music'}
# feature base {'music', 'film', 'story', 'element'}
# feature allow {'Michael'}
# feature name {'Peter', 'American', 'John', 'Michael'}
# feature serve set()
# feature run {'track'}
# feature show {'clip', 'film', 'Madonna', 'image', 'character', 'Peter', 'Harrison', 'footage', 'appearance', 'scene', 'Beyoncé', 'performance'}
# feature consider {'work', 'collaboration', 'music'}
# feature state set()
# feature start {'work', 'production', 'appearance'}
# feature get {'work'}
# feature record {'artist', 'song', 'vocal', 'music', 'track'}
# state be set()
# state have {'office', 'control'}
# state make {'law'}
# state include set()
# state use {'fund'}
# state do {'record'}
# state become {'law', 'governor'}
# state take {'office', 'control'}
# state write {'law', 'team', 'record'}
# state say set()
# state begin {'school'}
# state give {'control'}
# state know {'line', 'record'}
# state play set()
# state find set()
# state call set()
# state go set()
# state release {'title', 'party', 'record'}
# state win {'control', 'election', 'title', 'record', 'team', 'championship'}
# state lead {'team'}
# state receive {'funding', 'government'}
# state follow set()
# state leave {'office', 'politics', 'school'}
# state come {'record'}
# state remain {'team', 'fund'}
# state continue {'maintenance'}
# state describe set()
# state move set()
# state work {'title', 'team', 'party'}
# state hold {'election', 'court', 'government', 'record', 'office'}
# state appear set()
# state return {'visit', 'control', 'champion', 'route'}
# state see set()
# state build {'house', 'road'}
# state produce {'record'}
# state create set()
# state reach set()
# state provide {'funding', 'security', 'fund'}
# state base {'team'}
# state allow {'team', 'police'}
# state name {'team'}
# state serve {'route', 'senator', 'governor'}
# state run {'line', 'school', 'record'}
# state show set()
# state consider {'religion'}
# state feature set()
# state start {'house', 'line', 'school'}
# state get {'control'}
# state record {'level'}
# start be {'time'}
# start have {'time'}
# start make {'appearance', 'game', 'life'}
# start include {'work', 'construction', 'appearance'}
# start use {'time', 'development', 'material'}
# start do {'work'}
# start become set()
# start take {'position', 'time', 'order', 'place'}
# start write {'work', 'play', 'order', 'material'}
# start say set()
# start begin {'service', 'flight', 'play', 'life', 'work', 'September', 'negotiation', 'development', 'December', 'production', 'construction', 'operation', 'January', 'school'}
# start give {'point', 'time', 'order', 'life'}
# start know {'work', 'line', 'material'}
# start play {'game', 'time', 'shortstop', 'center', 'quarterback'}
# start find {'work', 'time', 'life', 'job'}
# start call {'center', 'time'}
# start go {'play', 'penalty', 'place'}
# start release {'game', 'September', 'point', 'December', 'date', 'January', 'material'}
# start win {'Game', 'game', 'point', 'stage', 'time', 'pitcher'}
# start lead {'time'}
# start receive {'order'}
# start follow {'World', 'order'}
# start leave {'school'}
# start come {'time'}
# start remain {'game', 'work', 'building', 'time', 'date', 'material'}
# start continue {'service', 'work', 'negotiation', 'development', 'production', 'operation'}
# start describe {'life'}
# start move {'production'}
# start work {'order', 'life', 'place'}
# start hold {'service', 'September', 'negotiation', 'position', 'fire', 'job', 'penalty'}
# start appear set()
# start return {'flight', 'game', 'position', 'fire', 'appearance', 'penalty'}
# start see {'service', 'life'}
# start build {'work', 'house', 'building', 'material'}
# start produce {'work', 'game'}
# start create {'life', 'game', 'work', 'position', 'job'}
# start reach {'position'}
# start provide {'service', 'fire', 'material'}
# start base {'service', 'game', 'salary', 'operation', 'construction', 'material'}
# start allow {'time', 'construction'}
# start name set()
# start serve {'time'}
# start run {'service', 'play', 'game', 'time', 'line', 'order', 'school'}
# start show {'center', 'appearance'}
# start consider {'work'}
# start feature {'work', 'production', 'appearance'}
# start state {'house', 'line', 'school'}
# start get {'point', 'work', 'time', 'job'}
# start record {'time', 'material'}
# get be {'home', 'nothing', 'woman', 'water', 'time', 'kind', 'people', 'something', 'anything'}
# get have {'control', 'something', 'nothing', 'wind', 'plenty', 'someone', 'everything', 'time', 'people', 'access', 'anything'}
# get make {'money', 'people', 'thing', 'something'}
# get include {'work', 'information', 'woman'}
# get use {'water', 'time', 'information', 'word'}
# get do {'justice', 'nothing', 'work', 'credit', 'everything', 'kind', 'thing', 'something', 'anything'}
# get become {'home', 'something'}
# get take {'home', 'control', 'credit', 'hold', 'revenge', 'time', 'inspiration'}
# get write {'home', 'word', 'work', 'credit', 'something', 'anything'}
# get say {'nothing', 'everything', 'thing', 'something', 'anything'}
# get begin {'work'}
# get give {'control', 'support', 'credit', 'advice', 'point', 'money', 'woman', 'permission', 'time', 'information', 'people', 'access'}
# get know {'nothing', 'work', 'everything', 'people', 'something', 'anything'}
# get play {'home', 'time', 'something'}
# get find {'food', 'nothing', 'work', 'support', 'someone', 'wind', 'water', 'time', 'information', 'job', 'inspiration', 'help', 'people', 'thing', 'something', 'anything'}
# get call {'home', 'Sam', 'time', 'attention'}
# get go {'home'}
# get release {'point', 'water', 'information'}
# get win {'home', 'control', 'support', 'point', 'time', 'shot'}
# get lead {'people', 'time'}
# get receive {'word', 'support', 'credit', 'attention', 'money', 'water', 'permission', 'information', 'help'}
# get follow set()
# get leave {'home', 'everything'}
# get come {'home', 'time'}
# get remain {'work', 'time'}
# get continue {'work', 'support'}
# get describe {'someone', 'something'}
# get move {'food', 'water', 'people', 'home'}
# get work {'woman', 'people'}
# get hold {'job'}
# get appear set()
# get return {'home', 'control'}
# get see {'nothing', 'someone', 'everything', 'Homer', 'everyone', 'people', 'thing', 'something', 'anything'}
# get build {'home', 'work', 'support', 'lot', 'something'}
# get produce {'work', 'wind', 'water', 'result', 'something', 'anything'}
# get create {'work', 'water', 'something', 'job'}
# get reach {'wind'}
# get provide {'food', 'support', 'advice', 'money', 'water', 'information', 'inspiration', 'access'}
# get base {'hit'}
# get allow {'woman', 'water', 'time', 'everyone', 'people', 'access'}
# get name {'Sam'}
# get serve {'justice', 'time', 'food'}
# get run {'water', 'support', 'home', 'time'}
# get show {'support', 'everyone', 'people', 'Homer'}
# get consider {'work', 'something', 'idea'}
# get feature {'work'}
# get state {'control'}
# get start {'point', 'work', 'time', 'job'}
# get record {'home', 'time', 'wind'}
# record be {'home', 'time', 'number'}
# record have {'time', 'wind'}
# record make {'history', 'music', 'player', 'use'}
# record include {'music', 'song'}
# record use {'technique', 'time', 'music', 'material'}
# record do {'music', 'song'}
# record become {'home'}
# record take {'home', 'time'}
# record write {'home', 'career', 'book', 'history', 'process', 'song', 'music', 'material'}
# record say set()
# record begin {'sale'}
# record give {'time', 'player', 'number'}
# record know {'use', 'book', 'artist', 'song', 'material'}
# record play {'home', 'contract', 'career', 'time', 'song', 'music'}
# record find {'mention', 'time', 'wind'}
# record call {'home', 'time'}
# record go {'home'}
# record release {'material', 'history', 'album', 'song', 'version', 'music', 'track'}
# record win {'home', 'time'}
# record lead {'artist', 'producer', 'time', 'player', 'vocal', 'company', 'track'}
# record receive set()
# record follow {'album', 'player'}
# record leave {'home'}
# record come {'home', 'time'}
# record remain {'track', 'number', 'time', 'song', 'player', 'material'}
# record continue {'use'}
# record describe set()
# record move {'equipment', 'home'}
# record work set()
# record hold {'company', 'industry', 'number'}
# record appear set()
# record return {'home', 'player'}
# record see {'use'}
# record build {'home', 'material'}
# record produce {'rainfall', 'book', 'wind', 'album', 'song', 'sound', 'version', 'music', 'track'}
# record create {'music', 'song'}
# record reach {'wind', 'sale', 'number'}
# record provide {'vocal', 'music', 'player', 'material'}
# record base {'company', 'version', 'music', 'material'}
# record allow {'company', 'time', 'player', 'use'}
# record name {'player'}
# record serve {'time', 'player'}
# record run {'home', 'number', 'time', 'victory', 'track'}
# record show {'producer'}
# record consider {'music'}
# record feature {'artist', 'song', 'vocal', 'music', 'track'}
# record state {'level'}
# record start {'time', 'material'}
# record get {'home', 'time', 'wind'}
